# %% [markdown]
# # Navigation Explorer
#
# Step-by-step navigation extraction with DFS exploration.

# %%
# 1. SETUP
import sys
from pathlib import Path

backend_path = Path.cwd().parent.parent
if str(backend_path) not in sys.path:
    sys.path.insert(0, str(backend_path))

from dotenv import load_dotenv
load_dotenv(backend_path.parent / 'config' / '.env')

print(f"Backend: {backend_path}")
print("Run next cell to start browser.")
# Out:
# Backend: /Users/bhavyajain/Code/fashion_archive/backend
# Run next cell to start browser.

# %%
# 2. BROWSER
from playwright.async_api import async_playwright

# Cleanup existing
async def cleanup():
    for name in ['browser', 'playwright']:
        if name in globals():
            try:
                obj = globals()[name]
                await (obj.close() if name == 'browser' else obj.stop())
            except: pass

await cleanup()

playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page(viewport={'width': 768, 'height': 900})

print("Browser ready.")
# Out:
# Browser ready.

# %%
# 3. RELOAD MODULES (run after code changes)
import sys

modules_to_clear = [
    'scraper.navigation.dynamic_explorer',
    'scraper.navigation.llm_popup_dismiss',
    'scraper.navigation.step_explorer',
    'scraper.navigation.extraction.nav_elements',
    'scraper.navigation.llm.classification',
    'scraper.navigation.llm.client',
    'step_explorer',
]
for mod in modules_to_clear:
    if mod in sys.modules:
        del sys.modules[mod]

from step_explorer import NavExplorer, run_exploration

# Test brands
BRANDS = {
    "axel_arigato": "https://www.axelarigato.com",
    "macys": "https://www.macys.com",
    "uniqlo": "https://www.uniqlo.com",
    "ounass": "https://www.ounass.ae/women",
    "entire_studios": "https://www.entirestudios.com",
    "eckhaus_latta": "https://www.eckhauslatta.com",
    "alexander_mcqueen": "https://www.alexandermcqueen.com",
    "balenciaga": "https://www.balenciaga.com",
    "zalando_kids": "https://www.zalando.de/kinder-home/",
    "aelfric_eden": "https://www.aelfriceden.com",
    "named_collective": "https://namedcollective.com",
    "two_fold_vintage": "https://twofoldvintage.com",
}

print(f"Modules reloaded. {len(BRANDS)} brands available.")
print("Brands:", list(BRANDS.keys()))
# Out:
# Modules reloaded. 12 brands available.
# Brands: ['axel_arigato', 'macys', 'uniqlo', 'ounass', 'entire_studios', 'eckhaus_latta', 'alexander_mcqueen', 'balenciaga', 'zalando_kids', 'aelfric_eden', 'named_collective', 'two_fold_vintage']

# %%
# 4. EXPLORE SINGLE BRAND
BRAND = "two_fold_vintage"  # <-- Change this

url = BRANDS[BRAND]
print(f"\n{'='*60}")
print(f"Exploring: {BRAND}")
print(f"URL: {url}")
print(f"{'='*60}\n")

result = await run_exploration(page, url, max_steps=100)

print(f"\n{'='*60}")
print(f"RESULTS: {BRAND}")
print(f"{'='*60}")
print(f"Success: {result['success']}")
print(f"Total links: {result['stats']['total_links']}")
print(f"Steps: {result['stats']['total_steps']}")
print(f"Errors: {result['stats']['errors']}")
if result['error']:
    print(f"Error: {result['error']}")
# Out:
# ============================================================
# Exploring: two_fold_vintage
# URL: https://twofoldvintage.com
# ============================================================
#
# [SETUP] Navigating to https://twofoldvintage.com
# [SETUP] Dismissing popups...
#   [Direct popup check]
#     [DIRECT] Clicked: button[aria-label="Close dialog"]
#   [LLM check 1/2]
#     LLM: REASON: I can see the main content of the webpage clearly with no popup, modal, cookie banner, or overlay blocking it.
#     LLM: NONE
#     No popup
#   [DOM removal]
# [SETUP] Opening menu...
#     [NAV] Scanning for menu elements and buttons...
#     [NAV] Found 10 menu candidates, 20 buttons
#     [NAV] LLM identified: Menu
#     [NAV] Clicked: button "Menu"
#     [NAV] Cached menu button: button:has-text("Menu") (click)
#     [ARIA-DIFF] 29 new lines appeared
#     [ARIA-DIFF] Container roles found: ['dialog', 'navigation']
#     [ARIA-DIFF] Found 2 candidate containers
#     [ARIA-DIFF] Using LLM to filter 2 containers
#     [LLM] EXCLUDE: 0
#
# The dialog container [0] should be excluded because it appears to be a mobile/overlay menu that contains account functions (Log in, Create account), search functionality, social media links, and secondary navigation items (About Us
#     [ARIA-DIFF] Using single container: navigation[0] (412 chars)
#     [MENU] Using ARIA diff menu (412 chars)
# [SETUP] Menu opened (412 chars)
# [SETUP] Menu selector: [aria-label="Primary"]
#   [Direct popup check SKIPPED - menu is open]
#   [LLM check 1/1]
#     LLM: REASON: This is a navigation menu dialog with categories, links, and account options, not a popup that blocks main content.
#     LLM:
#     LLM: NONE
#     No popup
#   [DOM removal SKIPPED - menu is open]
# [SETUP] Detecting tabs...
# [SETUP] Could not find tabs in DOM
# [SETUP] No tabs - analyzing menu content...
# [SETUP] Menu ARIA (412 chars):
#   - navigation "Primary":
#     - list:
#       - listitem:
#         - link "SHOP ALL":
#           - /url: /collections/all
#       - listitem:
#         - button "Categories"
#       - listitem:
#         - button "INFO"
#       - listitem:
#         - button "LIBRARY"
#       - listitem:
#         - link "GIFT CARD":
#           - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 5 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [button] INFO (url=None)
#     [button] LIBRARY (url=None)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 1
#     no-js-focus-wrapper (5 items):
#       - SHOP ALL
#       - Categories
#       - INFO
#       - LIBRARY
#       - GIFT CARD
#   [EXTRACT] Only 1 CSS group(s) - skipping LLM exclusion
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 5 elements
#     [LLM] Batch classification: expands=[]
# [SETUP] Expandable 'Categories': added to stack
# [SETUP] Expandable 'INFO': added to stack
# [SETUP] Expandable 'LIBRARY': added to stack
# [SETUP] Total: 2 links, 3 expandables
# [SETUP] Stack: ['Categories', 'INFO', 'LIBRARY']
#
# [STEP] LIBRARY (button)
#   Stack: 2 remaining
#   [ARIA BEFORE] 412 chars, 14 lines
#     - navigation "Primary":
#       - list:
#         - listitem:
#           - link "SHOP ALL":
#             - /url: /collections/all
#         - listitem:
#           - button "Categories"
#         - listitem:
#           - button "INFO"
#         - listitem:
#           - button "LIBRARY"
#         - listitem:
#           - link "GIFT CARD":
#             - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 5 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [button] INFO (url=None)
#     [button] LIBRARY (url=None)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 1
#     no-js-focus-wrapper (5 items):
#       - SHOP ALL
#       - Categories
#       - INFO
#       - LIBRARY
#       - GIFT CARD
#   [EXTRACT] Only 1 CSS group(s) - skipping LLM exclusion
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 5 elements
#   [CLICK] LIBRARY
#         [CLICK-DETAIL] Strict role search: only trying 'button'
#         [CLICK-DETAIL] button exact=True: 1 matches
#         [CLICK-DETAIL] Found 'LIBRARY' as button (#1 of 1, visible)
#   [ARIA AFTER] 611 chars, 21 lines
#     - navigation "Primary":
#       - list:
#         - listitem:
#           - link "SHOP ALL":
#             - /url: /collections/all
#         - listitem:
#           - button "Categories"
#         - listitem:
#           - button "INFO"
#         - listitem:
#           - button "LIBRARY" [expanded]
#           - list:
#             - listitem:
#               - link "Library":
#                 - /url: /blogs/library
#             - listitem:
#               - link "ARCHIVE":
#                 - /url: /collections/archive-1
#         - listitem:
#           - link "GIFT CARD":
#             - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXPAND] Content expanded in place (10% removed)
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 7 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [button] INFO (url=None)
#     [button] LIBRARY (url=None)
#     [link] Library (url=/blogs/library)
#     [link] ARCHIVE (url=/collections/archive-1)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 1
#     no-js-focus-wrapper (7 items):
#       - SHOP ALL
#       - Categories
#       - INFO
#       - LIBRARY
#       - Library
#       - ARCHIVE
#       - GIFT CARD
#   [EXTRACT] Only 1 CSS group(s) - skipping LLM exclusion
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 7 elements
#   [IN-PLACE] Using context-based diff (name + parent/nearby_link)
#   [DIFF] 2 new elements (by context):
#     [link] Library (idx:?, near:None)
#     [link] ARCHIVE (idx:?, near:None)
#   [NAV] Link: Library
#   [NAV] Link: ARCHIVE
#   [NAV] Total: 2 links added, 0 expandables queued
#   [TREE] Total categories: 4
#   [STACK] Added 0 (LIFO - last added = next to pop)
#   [STACK] (2 items, top first):
#     → INFO
#       Categories
#   [1] LIBRARY: 2 links, 0 children
#
# [STEP] INFO (button)
#   Stack: 1 remaining
#   [ARIA BEFORE] 611 chars, 21 lines
#     - navigation "Primary":
#       - list:
#         - listitem:
#           - link "SHOP ALL":
#             - /url: /collections/all
#         - listitem:
#           - button "Categories"
#         - listitem:
#           - button "INFO"
#         - listitem:
#           - button "LIBRARY" [expanded]
#           - list:
#             - listitem:
#               - link "Library":
#                 - /url: /blogs/library
#             - listitem:
#               - link "ARCHIVE":
#                 - /url: /collections/archive-1
#         - listitem:
#           - link "GIFT CARD":
#             - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 7 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [button] INFO (url=None)
#     [button] LIBRARY (url=None)
#     [link] Library (url=/blogs/library)
#     [link] ARCHIVE (url=/collections/archive-1)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 1
#     no-js-focus-wrapper (7 items):
#       - SHOP ALL
#       - Categories
#       - INFO
#       - LIBRARY
#       - Library
#       - ARCHIVE
#       - GIFT CARD
#   [EXTRACT] Only 1 CSS group(s) - skipping LLM exclusion
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 7 elements
#   [CLICK] INFO
#         [CLICK-DETAIL] Strict role search: only trying 'button'
#         [CLICK-DETAIL] button exact=True: 1 matches
#         [CLICK-DETAIL] Found 'INFO' as button (#1 of 1, visible)
#   [ARIA AFTER] 1116 chars, 37 lines
#     - navigation "Primary":
#       - list:
#         - listitem:
#           - link "SHOP ALL":
#             - /url: /collections/all
#         - listitem:
#           - button "Categories"
#         - listitem:
#           - button "INFO" [expanded]
#           - list:
#             - listitem:
#               - link "ABOUT US":
#                 - /url: /pages/about
#             - listitem:
#               - link "CONTACT":
#                 - /url: /pages/contact
#             - listitem:
#               - link "SHIPPING & RETURNS":
#                 - /url: /pages/shipping-and-returns
#             - listitem:
#               - link "GARMENT SIZING":
#                 - /url: /pages/sizing
#             - listitem:
#               - link "SHOWROOM APPOINTMENTS":
#                 - /url: /blogs/library/showroom-appointments
#         - listitem:
#           - button "LIBRARY" [expanded]
#           - list:
#             - listitem:
#               - link "Library":
#                 - /url: /blogs/library
#             - listitem:
#               - link "ARCHIVE":
#                 - /url: /collections/archive-1
#         - listitem:
#           - link "GIFT CARD":
#             - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXPAND] Content expanded in place (6% removed)
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 12 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [button] INFO (url=None)
#     [link] ABOUT US (url=/pages/about)
#     [link] CONTACT (url=/pages/contact)
#     [link] SHIPPING & RETURNS (url=/pages/shipping-and-returns)
#     [link] GARMENT SIZING (url=/pages/sizing)
#     [link] SHOWROOM APPOINTMENTS (url=/blogs/library/showroom-appointments)
#     [button] LIBRARY (url=None)
#     [link] Library (url=/blogs/library)
#     [link] ARCHIVE (url=/collections/archive-1)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 1
#     no-js-focus-wrapper (12 items):
#       - SHOP ALL
#       - Categories
#       - INFO
#       - ABOUT US
#       - CONTACT
#       - SHIPPING & RETURNS
#       - GARMENT SIZING
#       - SHOWROOM APPOINTMENTS
#       - LIBRARY
#       - Library
#       - ARCHIVE
#       - GIFT CARD
#   [EXTRACT] Only 1 CSS group(s) - skipping LLM exclusion
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 12 elements
#   [IN-PLACE] Using context-based diff (name + parent/nearby_link)
#   [DIFF] 5 new elements (by context):
#     [link] ABOUT US (idx:?, near:None)
#     [link] CONTACT (idx:?, near:None)
#     [link] SHIPPING & RETURNS (idx:?, near:None)
#     [link] GARMENT SIZING (idx:?, near:None)
#     [link] SHOWROOM APPOINTMENTS (idx:?, near:None)
#   [NAV] Link: ABOUT US
#   [NAV] Link: CONTACT
#   [NAV] Link: SHIPPING & RETURNS
#   [NAV] Link: GARMENT SIZING
#   [NAV] Link: SHOWROOM APPOINTMENTS
#   [NAV] Total: 5 links added, 0 expandables queued
#   [TREE] Total categories: 9
#   [STACK] Added 0 (LIFO - last added = next to pop)
#   [STACK] (1 items, top first):
#     → Categories
#   [2] INFO: 5 links, 0 children
#
# [STEP] Categories (button)
#   Stack: 0 remaining
#   [ARIA BEFORE] 1116 chars, 37 lines
#     - navigation "Primary":
#       - list:
#         - listitem:
#           - link "SHOP ALL":
#             - /url: /collections/all
#         - listitem:
#           - button "Categories"
#         - listitem:
#           - button "INFO" [expanded]
#           - list:
#             - listitem:
#               - link "ABOUT US":
#                 - /url: /pages/about
#             - listitem:
#               - link "CONTACT":
#                 - /url: /pages/contact
#             - listitem:
#               - link "SHIPPING & RETURNS":
#                 - /url: /pages/shipping-and-returns
#             - listitem:
#               - link "GARMENT SIZING":
#                 - /url: /pages/sizing
#             - listitem:
#               - link "SHOWROOM APPOINTMENTS":
#                 - /url: /blogs/library/showroom-appointments
#         - listitem:
#           - button "LIBRARY" [expanded]
#           - list:
#             - listitem:
#               - link "Library":
#                 - /url: /blogs/library
#             - listitem:
#               - link "ARCHIVE":
#                 - /url: /collections/archive-1
#         - listitem:
#           - link "GIFT CARD":
#             - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 12 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [button] INFO (url=None)
#     [link] ABOUT US (url=/pages/about)
#     [link] CONTACT (url=/pages/contact)
#     [link] SHIPPING & RETURNS (url=/pages/shipping-and-returns)
#     [link] GARMENT SIZING (url=/pages/sizing)
#     [link] SHOWROOM APPOINTMENTS (url=/blogs/library/showroom-appointments)
#     [button] LIBRARY (url=None)
#     [link] Library (url=/blogs/library)
#     [link] ARCHIVE (url=/collections/archive-1)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 1
#     no-js-focus-wrapper (12 items):
#       - SHOP ALL
#       - Categories
#       - INFO
#       - ABOUT US
#       - CONTACT
#       - SHIPPING & RETURNS
#       - GARMENT SIZING
#       - SHOWROOM APPOINTMENTS
#       - LIBRARY
#       - Library
#       - ARCHIVE
#       - GIFT CARD
#   [EXTRACT] Only 1 CSS group(s) - skipping LLM exclusion
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 12 elements
#   [CLICK] Categories
#         [CLICK-DETAIL] Strict role search: only trying 'button'
#         [CLICK-DETAIL] button exact=True: 1 matches
#         [CLICK-DETAIL] Found 'Categories' as button (#1 of 1, visible)
#   [ARIA AFTER] 1650 chars, 55 lines
#     - navigation "Primary":
#       - list:
#         - listitem:
#           - link "SHOP ALL":
#             - /url: /collections/all
#         - listitem:
#           - button "Categories" [expanded]
#           - list:
#             - listitem:
#               - link "Tees":
#                 - /url: /collections/tees-1
#             - listitem:
#               - link "Bottoms":
#                 - /url: /collections/pants
#             - listitem:
#               - link "Outerwear":
#                 - /url: /collections/outerwear-1
#             - listitem:
#               - link "Sweatshirt":
#                 - /url: /collections/sweatshirts
#             - listitem:
#               - link "Button Ups":
#                 - /url: /collections/shirts-1
#             - listitem:
#               - button "Collections"
#         - listitem:
#           - button "INFO" [expanded]
#           - list:
#             - listitem:
#               - link "ABOUT US":
#                 - /url: /pages/about
#             - listitem:
#               - link "CONTACT":
#                 - /url: /pages/contact
#             - listitem:
#               - link "SHIPPING & RETURNS":
#                 - /url: /pages/shipping-and-returns
#             - listitem:
#               - link "GARMENT SIZING":
#                 - /url: /pages/sizing
#             - listitem:
#               - link "SHOWROOM APPOINTMENTS":
#                 - /url: /blogs/library/showroom-appointments
#         - listitem:
#           - button "LIBRARY" [expanded]
#           - list:
#             - listitem:
#               - link "Library":
#                 - /url: /blogs/library
#             - listitem:
#               - link "ARCHIVE":
#                 - /url: /collections/archive-1
#         - listitem:
#           - link "GIFT CARD":
#             - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXPAND] Content expanded in place (4% removed)
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 18 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [link] Tees (url=/collections/tees-1)
#     [link] Bottoms (url=/collections/pants)
#     [link] Outerwear (url=/collections/outerwear-1)
#     [link] Sweatshirt (url=/collections/sweatshirts)
#     [link] Button Ups (url=/collections/shirts-1)
#     [button] Collections (url=None)
#     [button] INFO (url=None)
#     [link] ABOUT US (url=/pages/about)
#     [link] CONTACT (url=/pages/contact)
#     [link] SHIPPING & RETURNS (url=/pages/shipping-and-returns)
#     [link] GARMENT SIZING (url=/pages/sizing)
#     [link] SHOWROOM APPOINTMENTS (url=/blogs/library/showroom-appointments)
#     [button] LIBRARY (url=None)
#     [link] Library (url=/blogs/library)
#     [link] ARCHIVE (url=/collections/archive-1)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 1
#     no-js-focus-wrapper (18 items):
#       - SHOP ALL
#       - Categories
#       - Tees
#       - Bottoms
#       - Outerwear
#       - Sweatshirt
#       - Button Ups
#       - Collections
#       - INFO
#       - ABOUT US
#       - CONTACT
#       - SHIPPING & RETURNS
#       - GARMENT SIZING
#       - SHOWROOM APPOINTMENTS
#       - LIBRARY
#       - Library
#       - ARCHIVE
#       - GIFT CARD
#   [EXTRACT] Only 1 CSS group(s) - skipping LLM exclusion
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 18 elements
#   [IN-PLACE] Using context-based diff (name + parent/nearby_link)
#   [DIFF] 6 new elements (by context):
#     [link] Tees (idx:?, near:None)
#     [link] Bottoms (idx:?, near:None)
#     [link] Outerwear (idx:?, near:None)
#     [link] Sweatshirt (idx:?, near:None)
#     [link] Button Ups (idx:?, near:None)
#     [button] Collections (idx:?, near:Button Ups)
#     [LLM] Batch classification: expands=[]
#   [NAV] Link: Tees
#   [NAV] Link: Bottoms
#   [NAV] Link: Outerwear
#   [NAV] Link: Sweatshirt
#   [NAV] Link: Button Ups
#   [NAV] Expandable: Collections (added to stack)
#   [NAV] Total: 5 links added, 1 expandables queued
#   [TREE] Total categories: 14
#   [STACK] Added 1 (LIFO - last added = next to pop)
#   [STACK] (1 items, top first):
#     → Categories > Categories > Collections
#   [3] Categories: 5 links, 1 children
#
# [STEP] Categories > Categories > Collections (button)
#   Stack: 0 remaining
#   [ARIA BEFORE] 1650 chars, 55 lines
#     - navigation "Primary":
#       - list:
#         - listitem:
#           - link "SHOP ALL":
#             - /url: /collections/all
#         - listitem:
#           - button "Categories" [expanded]
#           - list:
#             - listitem:
#               - link "Tees":
#                 - /url: /collections/tees-1
#             - listitem:
#               - link "Bottoms":
#                 - /url: /collections/pants
#             - listitem:
#               - link "Outerwear":
#                 - /url: /collections/outerwear-1
#             - listitem:
#               - link "Sweatshirt":
#                 - /url: /collections/sweatshirts
#             - listitem:
#               - link "Button Ups":
#                 - /url: /collections/shirts-1
#             - listitem:
#               - button "Collections"
#         - listitem:
#           - button "INFO" [expanded]
#           - list:
#             - listitem:
#               - link "ABOUT US":
#                 - /url: /pages/about
#             - listitem:
#               - link "CONTACT":
#                 - /url: /pages/contact
#             - listitem:
#               - link "SHIPPING & RETURNS":
#                 - /url: /pages/shipping-and-returns
#             - listitem:
#               - link "GARMENT SIZING":
#                 - /url: /pages/sizing
#             - listitem:
#               - link "SHOWROOM APPOINTMENTS":
#                 - /url: /blogs/library/showroom-appointments
#         - listitem:
#           - button "LIBRARY" [expanded]
#           - list:
#             - listitem:
#               - link "Library":
#                 - /url: /blogs/library
#             - listitem:
#               - link "ARCHIVE":
#                 - /url: /collections/archive-1
#         - listitem:
#           - link "GIFT CARD":
#             - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 18 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [link] Tees (url=/collections/tees-1)
#     [link] Bottoms (url=/collections/pants)
#     [link] Outerwear (url=/collections/outerwear-1)
#     [link] Sweatshirt (url=/collections/sweatshirts)
#     [link] Button Ups (url=/collections/shirts-1)
#     [button] Collections (url=None)
#     [button] INFO (url=None)
#     [link] ABOUT US (url=/pages/about)
#     [link] CONTACT (url=/pages/contact)
#     [link] SHIPPING & RETURNS (url=/pages/shipping-and-returns)
#     [link] GARMENT SIZING (url=/pages/sizing)
#     [link] SHOWROOM APPOINTMENTS (url=/blogs/library/showroom-appointments)
#     [button] LIBRARY (url=None)
#     [link] Library (url=/blogs/library)
#     [link] ARCHIVE (url=/collections/archive-1)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 1
#     no-js-focus-wrapper (18 items):
#       - SHOP ALL
#       - Categories
#       - Tees
#       - Bottoms
#       - Outerwear
#       - Sweatshirt
#       - Button Ups
#       - Collections
#       - INFO
#       - ABOUT US
#       - CONTACT
#       - SHIPPING & RETURNS
#       - GARMENT SIZING
#       - SHOWROOM APPOINTMENTS
#       - LIBRARY
#       - Library
#       - ARCHIVE
#       - GIFT CARD
#   [EXTRACT] Only 1 CSS group(s) - skipping LLM exclusion
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 18 elements
#   [CLICK] Collections
#         [CLICK-DETAIL] Strict role search: only trying 'button'
#         [CLICK-DETAIL] button exact=True: 1 matches
#         [CLICK-DETAIL] Found 'Collections' as button (#1 of 1, visible)
#   [ARIA AFTER] 2105 chars, 68 lines
#     - navigation "Primary":
#       - list:
#         - listitem:
#           - link "SHOP ALL":
#             - /url: /collections/all
#         - listitem:
#           - button "Categories" [expanded]
#           - list:
#             - listitem:
#               - link "Tees":
#                 - /url: /collections/tees-1
#             - listitem:
#               - link "Bottoms":
#                 - /url: /collections/pants
#             - listitem:
#               - link "Outerwear":
#                 - /url: /collections/outerwear-1
#             - listitem:
#               - link "Sweatshirt":
#                 - /url: /collections/sweatshirts
#             - listitem:
#               - link "Button Ups":
#                 - /url: /collections/shirts-1
#             - listitem:
#               - button "Collections" [expanded]
#               - list:
#                 - listitem:
#                   - link "Band Tees":
#                     - /url: /collections/band-tees-1
#                 - listitem:
#                   - link "Two Fold":
#                     - /url: /collections/designer
#                 - listitem:
#                   - link "Chrome Hearts":
#                     - /url: /collections/chrome-hearts
#                 - listitem:
#                   - link "50% OFF":
#                     - /url: /collections/clearance
#         - listitem:
#           - button "INFO" [expanded]
#           - list:
#             - listitem:
#               - link "ABOUT US":
#                 - /url: /pages/about
#             - listitem:
#               - link "CONTACT":
#                 - /url: /pages/contact
#             - listitem:
#               - link "SHIPPING & RETURNS":
#                 - /url: /pages/shipping-and-returns
#             - listitem:
#               - link "GARMENT SIZING":
#                 - /url: /pages/sizing
#             - listitem:
#               - link "SHOWROOM APPOINTMENTS":
#                 - /url: /blogs/library/showroom-appointments
#         - listitem:
#           - button "LIBRARY" [expanded]
#           - list:
#             - listitem:
#               - link "Library":
#                 - /url: /blogs/library
#             - listitem:
#               - link "ARCHIVE":
#                 - /url: /collections/archive-1
#         - listitem:
#           - link "GIFT CARD":
#             - /url: https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
#   [EXPAND] Content expanded in place (3% removed)
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 22 elements from ARIA:
#     [link] SHOP ALL (url=/collections/all)
#     [button] Categories (url=None)
#     [link] Tees (url=/collections/tees-1)
#     [link] Bottoms (url=/collections/pants)
#     [link] Outerwear (url=/collections/outerwear-1)
#     [link] Sweatshirt (url=/collections/sweatshirts)
#     [link] Button Ups (url=/collections/shirts-1)
#     [button] Collections (url=None)
#     [link] Band Tees (url=/collections/band-tees-1)
#     [link] Two Fold (url=/collections/designer)
#     [link] Chrome Hearts (url=/collections/chrome-hearts)
#     [link] 50% OFF (url=/collections/clearance)
#     [button] INFO (url=None)
#     [link] ABOUT US (url=/pages/about)
#     [link] CONTACT (url=/pages/contact)
#     [link] SHIPPING & RETURNS (url=/pages/shipping-and-returns)
#     [link] GARMENT SIZING (url=/pages/sizing)
#     [link] SHOWROOM APPOINTMENTS (url=/blogs/library/showroom-appointments)
#     [button] LIBRARY (url=None)
#     [link] Library (url=/blogs/library)
#     [link] ARCHIVE (url=/collections/archive-1)
#     [link] GIFT CARD (url=https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web)
#   [EXTRACT] CSS groups: 2
#     no-js-focus-wrapper (18 items):
#       - SHOP ALL
#       - Categories
#       - Tees
#       - Bottoms
#       - Outerwear
#       - Sweatshirt
#       - Button Ups
#       - Collections
#       - INFO
#       - ABOUT US
#       - CONTACT
#       - SHIPPING & RETURNS
#       - GARMENT SIZING
#       - SHOWROOM APPOINTMENTS
#       - LIBRARY
#       - Library
#       - ARCHIVE
#       - GIFT CARD
#     li (4 items):
#       - Band Tees
#       - Two Fold
#       - Chrome Hearts
#       - 50% OFF
#     LLM exclusion response: {"exclude": [], "reason": "all are product categories and collections"}
#     LLM reason: all are product categories and collections
#   [EXTRACT] LLM excluded groups: set()
#   [EXTRACT] excluded_groups=set()
#   [EXTRACT] After CSS filter: 22 elements
#   [IN-PLACE] Using context-based diff (name + parent/nearby_link)
#   [DIFF] 4 new elements (by context):
#     [link] Band Tees (idx:?, near:None)
#     [link] Two Fold (idx:?, near:None)
#     [link] Chrome Hearts (idx:?, near:None)
#     [link] 50% OFF (idx:?, near:None)
#   [NAV] Link: Band Tees
#   [NAV] Link: Two Fold
#   [NAV] Link: Chrome Hearts
#   [NAV] Link: 50% OFF
#   [NAV] Total: 4 links added, 0 expandables queued
#   [TREE] Total categories: 18
#   [STACK] Added 0 (LIFO - last added = next to pop)
#   [STACK] (0 items, top first):
#   [4] Collections: 4 links, 0 children
#
# ============================================================
# RESULTS: two_fold_vintage
# ============================================================
# Success: True
# Total links: 18
# Steps: 4
# Errors: 0

# %%
# 5. SHOW RAW CATEGORIES (before tree processing)
if 'result' in dir() and result.get('categories'):
    categories = result['categories']
    print(f"\nRaw Categories ({len(categories)} total):")
    print("-" * 40)
    for path, url in sorted(categories.items()):
        print(f"{path}")
        print(f"  → {url}")
else:
    print("No results. Run exploration first.")
# Out:
# Raw Categories (18 total):
# ----------------------------------------
# Categories > Categories > Bottoms
#   → https://twofoldvintage.com/collections/pants
# Categories > Categories > Button Ups
#   → https://twofoldvintage.com/collections/shirts-1
# Categories > Categories > Collections > Collections > 50% OFF
#   → https://twofoldvintage.com/collections/clearance
# Categories > Categories > Collections > Collections > Band Tees
#   → https://twofoldvintage.com/collections/band-tees-1
# Categories > Categories > Collections > Collections > Chrome Hearts
#   → https://twofoldvintage.com/collections/chrome-hearts
# Categories > Categories > Collections > Collections > Two Fold
#   → https://twofoldvintage.com/collections/designer
# Categories > Categories > Outerwear
#   → https://twofoldvintage.com/collections/outerwear-1
# Categories > Categories > Sweatshirt
#   → https://twofoldvintage.com/collections/sweatshirts
# Categories > Categories > Tees
#   → https://twofoldvintage.com/collections/tees-1
# GIFT CARD
#   → https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
# INFO > INFO > ABOUT US
#   → https://twofoldvintage.com/pages/about
# INFO > INFO > CONTACT
#   → https://twofoldvintage.com/pages/contact
# INFO > INFO > GARMENT SIZING
#   → https://twofoldvintage.com/pages/sizing
# INFO > INFO > SHIPPING & RETURNS
#   → https://twofoldvintage.com/pages/shipping-and-returns
# INFO > INFO > SHOWROOM APPOINTMENTS
#   → https://twofoldvintage.com/blogs/library/showroom-appointments
# LIBRARY > LIBRARY > ARCHIVE
#   → https://twofoldvintage.com/collections/archive-1
# LIBRARY > LIBRARY > Library
#   → https://twofoldvintage.com/blogs/library
# SHOP ALL
#   → https://twofoldvintage.com/collections/all

# %%
# 6. SHOW PROCESSED TREE (with collapsed duplicates)
from step_explorer import categories_to_tree

if 'result' in dir() and result.get('categories'):
    tree = categories_to_tree(result['categories'])
    
    def print_tree(node, indent=0):
        prefix = "  " * indent
        # Print links at this level
        for link in node.get('links', []):
            print(f"{prefix}├── {link['name']} → {link['url']}")
        # Print children (folders)
        children = node.get('children', [])
        for i, child in enumerate(children):
            is_last = (i == len(children) - 1)
            print(f"{prefix}{'└' if is_last else '├'}── 📁 {child['name']}")
            print_tree(child, indent + 1)
    
    print(f"\nProcessed Tree (duplicates collapsed):")
    print("-" * 50)
    print_tree(tree)
else:
    print("No results. Run exploration first.")
# Out:
# Processed Tree (duplicates collapsed):
# --------------------------------------------------
# ├── SHOP ALL → https://twofoldvintage.com/collections/all
# ├── GIFT CARD → https://twofoldvintage.com/products/two-fold-gift-card?utm_source=copyToPasteBoard&utm_medium=product-links&utm_content=web
# ├── 📁 LIBRARY
#   ├── Library → https://twofoldvintage.com/blogs/library
#   ├── ARCHIVE → https://twofoldvintage.com/collections/archive-1
# ├── 📁 INFO
#   ├── ABOUT US → https://twofoldvintage.com/pages/about
#   ├── CONTACT → https://twofoldvintage.com/pages/contact
#   ├── SHIPPING & RETURNS → https://twofoldvintage.com/pages/shipping-and-returns
#   ├── GARMENT SIZING → https://twofoldvintage.com/pages/sizing
#   ├── SHOWROOM APPOINTMENTS → https://twofoldvintage.com/blogs/library/showroom-appointments
# └── 📁 Categories
#   ├── Tees → https://twofoldvintage.com/collections/tees-1
#   ├── Bottoms → https://twofoldvintage.com/collections/pants
#   ├── Outerwear → https://twofoldvintage.com/collections/outerwear-1
#   ├── Sweatshirt → https://twofoldvintage.com/collections/sweatshirts
#   ├── Button Ups → https://twofoldvintage.com/collections/shirts-1
#   └── 📁 Collections
#     ├── Band Tees → https://twofoldvintage.com/collections/band-tees-1
#     ├── Two Fold → https://twofoldvintage.com/collections/designer
#     ├── Chrome Hearts → https://twofoldvintage.com/collections/chrome-hearts
#     ├── 50% OFF → https://twofoldvintage.com/collections/clearance

# %%
# 7. MANUAL STEP-BY-STEP (for debugging)
# Create explorer manually
explorer = NavExplorer(page)

# Setup
URL = BRANDS["two_fold_vintage"]
setup_result = await explorer.setup(URL)
print(setup_result)

# %%
# 8. RUN SINGLE STEP (re-run to continue)
if not explorer.done():
    result = await explorer.step()
    print(f"\nItem: {result.item_name}")
    print(f"Success: {result.success}")
    print(f"Links: {list(result.links_found.keys()) if result.links_found else []}")
    print(f"Children: {result.children_added}")
    if result.error:
        print(f"Error: {result.error}")
else:
    print("Exploration complete!")
    explorer.print_tree()

# %%
# 9. SHOW EXPLORER STATE
explorer.show_state()
explorer.print_tree()
