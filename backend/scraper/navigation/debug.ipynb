# %% [markdown]
# # Navigation Scraper Debug Notebook
#
# Test navigation extraction on multiple brands. Always loops through the brand list.

# %%
# Setup - Run this first
import sys
from pathlib import Path

# Add backend to path
backend_path = Path.cwd().parent.parent
if str(backend_path) not in sys.path:
    sys.path.insert(0, str(backend_path))

# Load env
from dotenv import load_dotenv
load_dotenv(backend_path.parent / 'config' / '.env')

print(f"Backend path: {backend_path}")
print("Setup complete. Run browser cell next.")
# Out:
# Backend path: /Users/bhavyajain/Code/fashion_archive/backend
# Setup complete. Run browser cell next.

# %%
# Start browser (handles existing browser)
from playwright.async_api import async_playwright

# Helper function for cleanup - used throughout notebook
def reload_modules():
    """Reload all navigation modules to pick up code changes."""
    import importlib
    import sys
    modules_to_clear = [
        'scraper.navigation.dynamic_explorer',
        'scraper.navigation.step_explorer',
        'scraper.navigation.extraction.links',
        'scraper.navigation.aria.elements',
        'scraper.navigation.aria.diff',
        'scraper.navigation.menu.context',
        'scraper.navigation.llm.classification',
        'scraper.navigation.llm.client',
        'dynamic_explorer',
        'step_explorer'
    ]
    for mod in modules_to_clear:
        if mod in sys.modules:
            del sys.modules[mod]
    # Re-import dynamic_explorer
    import scraper.navigation.dynamic_explorer as de
    globals()['dynamic_explorer'] = de
    return de

# Close existing browser if any
async def cleanup_browser():
    global browser, playwright
    try:
        if 'browser' in globals() and browser is not None:
            await browser.close()
    except:
        pass
    try:
        if 'playwright' in globals() and playwright is not None:
            await playwright.stop()
    except:
        pass

await cleanup_browser()

# Start fresh
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page(viewport={'width': 768, 'height': 900})

# Import dynamic_explorer
import scraper.navigation.dynamic_explorer as dynamic_explorer

print("Browser started. reload_modules() available.")
# Out:
# Browser started. reload_modules() available.

# %%
# =============================================================================
# TEST BRANDS - Comment/uncomment to choose which to test
# =============================================================================

TEST_BRANDS = {
    "entire_studios": "https://www.entirestudios.com",
    "prod_bldg": "https://prod.net",
    "named_collective": "https://namedcollective.com",
    "alexander_mcqueen": "https://www.alexandermcqueen.com",
    "balenciaga": "https://www.balenciaga.com",
    "zalando_kids": "https://www.zalando.de/kinder-home/",
    "uniqlo": "https://www.uniqlo.com",
    "aelfric_eden": "https://www.aelfriceden.com",
    "eckhaus_latta": "https://www.eckhauslatta.com",
    "axel_arigato": "https://www.axelarigato.com",
}

# Comment out brands you don't want to test:
ACTIVE_BRANDS = [
    "entire_studios",
    "prod_bldg",
    "named_collective",
    "alexander_mcqueen",
    "balenciaga",
    "zalando_kids",
    "uniqlo",
    "aelfric_eden",
    "eckhaus_latta",
    "axel_arigato",
]

print(f"Testing {len(ACTIVE_BRANDS)} brands")

# %%
# =============================================================================
# TEST: Open menu and capture ARIA diff for all brands
# =============================================================================
reload_modules()

results = {}
for brand in ACTIVE_BRANDS:
    url = TEST_BRANDS[brand]
    print(f"\n{'='*60}")
    print(f"{brand}")
    print(f"{'='*60}")
    
    try:
        await page.goto(url, wait_until="domcontentloaded")
        await page.wait_for_timeout(1500)
        
        # Open menu and capture before/after diff
        result = await dynamic_explorer.open_menu_and_capture(page)
        
        if not result['opened']:
            print("  ❌ Menu not opened")
            results[brand] = {"status": "❌ Menu not opened"}
            continue
        
        if result['menu_start']:
            line_idx, first_line = result['menu_start']
            saved = len(result['after_aria']) - len(result['menu_aria'])
            print(f"  ✅ Menu opened")
            print(f"     Menu starts at line {line_idx}")
            print(f"     First new: {first_line}")
            print(f"     Saved: {saved} chars")
            print(f"\n--- MENU ARIA ({len(result['menu_aria'])} chars) ---")
            print(result['menu_aria'])
            results[brand] = {
                "status": "✅",
                "line": line_idx,
                "first_new": first_line,
                "saved": saved,
                "result": result
            }
        else:
            print("  ⚠️ Menu opened but no ARIA diff detected")
            print(f"\n--- FULL ARIA (no diff) ---")
            print(result['after_aria'][:5000])
            results[brand] = {"status": "⚠️ No diff", "result": result}
            
    except Exception as e:
        print(f"  ⚠️ Error: {e}")
        results[brand] = {"status": f"⚠️ ERROR: {str(e)[:30]}"}

print(f"\n{'='*60}")
print("SUMMARY")
print(f"{'='*60}")
for brand, r in results.items():
    status = r['status']
    extra = f" | Line {r['line']}, saved {r['saved']} chars" if r.get('saved') else ""
    print(f"  {brand:20} {status}{extra}")

# %%
# =============================================================================
# OPTIONAL: Manually set cached results (skip LLM entirely)
# Uncomment and edit if you already know the tab names from previous runs
# =============================================================================

# CACHED_RESULTS = {
#     "uniqlo": {
#         "status": "ok",
#         "url": "https://www.uniqlo.com",
#         "tabs": [
#             {"text": "women", "role": "tab", "x": 24, "y": 64},
#             {"text": "men", "role": "tab", "x": 252, "y": 64},
#             {"text": "kids", "role": "tab", "x": 476, "y": 64},
#             {"text": "baby", "role": "tab", "x": 700, "y": 64},
#         ],
#         "menu_aria": None  # Not needed for interaction
#     },
#     "axel_arigato": {
#         "status": "ok",
#         "url": "https://www.axelarigato.com",
#         "tabs": [
#             {"text": "Men", "role": "button", "x": 0, "y": 46},
#             {"text": "Women", "role": "button", "x": 384, "y": 46},
#         ],
#         "menu_aria": None
#     },
# }
# print(f"Manually set {len(CACHED_RESULTS)} cached results")

# %%
# =============================================================================
# STEP 1: Detect tabs (runs LLM) - SAVE RESULTS
# Run this ONCE, then use cached results in subsequent cells
# =============================================================================
reload_modules()
from IPython.display import display, Image
import importlib
import scraper.navigation.llm_popup_dismiss as popup_module
importlib.reload(popup_module)
from scraper.navigation.llm_popup_dismiss import dismiss_popups_with_llm
import json

# Cache to store results - persists across cell runs
CACHED_RESULTS = {}

for brand in ACTIVE_BRANDS:
    url = TEST_BRANDS[brand]
    print(f"\n{'='*70}")
    print(f"{brand}")
    print(f"{'='*70}")
    
    try:
        await page.goto(url, wait_until="domcontentloaded")
        await page.wait_for_timeout(1500)
        
        # Dismiss popups BEFORE menu opens
        await page.wait_for_timeout(500)
        await dismiss_popups_with_llm(page, max_attempts=2)
        
        # Open menu
        result = await dynamic_explorer.open_menu_and_capture(page)
        
        if not result['opened']:
            print("  ❌ Menu not opened")
            CACHED_RESULTS[brand] = {"status": "no_menu", "tabs": None, "menu_aria": None}
            continue
        
        print("  ✅ Menu opened")
        
        # Dismiss popups AFTER menu - use menu_is_open=True!
        await page.wait_for_timeout(500)
        await dismiss_popups_with_llm(page, max_attempts=1, menu_is_open=True)
        
        # Take screenshot for display only (not sending to LLM again)
        screenshot = await page.screenshot()
        display(Image(data=screenshot, width=400))
        
        # Identify tabs (LLM call)
        llm_result = await dynamic_explorer.identify_tabs_with_llm(page, result['menu_aria'])
        print(f"  LLM tab names: {llm_result['tab_names']}")
        
        if not llm_result['tab_names']:
            CACHED_RESULTS[brand] = {
                "status": "no_tabs",
                "tabs": None,
                "menu_aria": result['menu_aria']
            }
            continue
        
        # Find tabs in DOM
        dom_result = await dynamic_explorer.find_tabs_in_dom(
            page, llm_result['tab_names'], result['menu_aria']
        )
        
        if dom_result['found']:
            print(f"  ✅ Found {len(dom_result['tabs'])} tabs: {[t['text'] for t in dom_result['tabs']]}")
            CACHED_RESULTS[brand] = {
                "status": "ok",
                "tabs": dom_result['tabs'],
                "menu_aria": result['menu_aria'],
                "url": url
            }
        else:
            CACHED_RESULTS[brand] = {
                "status": "tabs_not_found",
                "tabs": None,
                "menu_aria": result['menu_aria']
            }
            
    except Exception as e:
        print(f"  ⚠️ Error: {e}")
        CACHED_RESULTS[brand] = {"status": "error", "tabs": None, "menu_aria": None}

print(f"\n{'='*70}")
print("CACHED RESULTS (use in next cell without re-running LLM)")
print(f"{'='*70}")
for brand, r in CACHED_RESULTS.items():
    if r['tabs']:
        print(f"  {brand:20} ✅ {[t['text'] for t in r['tabs']]}")
    else:
        print(f"  {brand:20} {r['status']}")

# %%
# =============================================================================
# STEP 2: Click/hover tabs using CACHED results (NO LLM calls)
# Uses CACHED_RESULTS from previous cell
# =============================================================================
reload_modules()
import importlib
import scraper.navigation.llm_popup_dismiss as popup_module
importlib.reload(popup_module)
from scraper.navigation.llm_popup_dismiss import dismiss_popups_with_llm

# Check if we have cached results
if not CACHED_RESULTS:
    print("❌ No cached results! Run STEP 1 first.")
else:
    for brand, cached in CACHED_RESULTS.items():
        if cached['status'] != 'ok' or not cached['tabs']:
            print(f"\n{brand}: Skipping (status={cached['status']})")
            continue
            
        url = cached['url']
        tabs = cached['tabs']
        menu_aria = cached['menu_aria']
        
        print(f"\n{'='*70}")
        print(f"{brand} - Using cached tabs: {[t['text'] for t in tabs]}")
        print(f"{'='*70}")
        
        try:
            # Navigate and open menu
            await page.goto(url, wait_until="domcontentloaded")
            await page.wait_for_timeout(1500)
            
            await page.wait_for_timeout(500)
            await dismiss_popups_with_llm(page, max_attempts=2)
            
            result = await dynamic_explorer.open_menu_and_capture(page)
            if not result['opened']:
                print("  ❌ Menu not opened")
                continue
            
            # IMPORTANT: menu_is_open=True after menu opens!
            await page.wait_for_timeout(500)
            await dismiss_popups_with_llm(page, max_attempts=1, menu_is_open=True)
            
            # Interact with each cached tab (NO LLM calls)
            for tab in tabs:
                print(f"\n  {'─'*60}")
                print(f"  TAB: {tab['text']} (role={tab['role']})")
                print(f"  {'─'*60}")
                
                try:
                    # FIRST: Try hover
                    revealed, aria_after = await dynamic_explorer.hover_and_check(
                        page, tab['text'], item_type=tab['role']
                    )
                    
                    if revealed:
                        print(f"    ✅ Hover revealed content")
                        tab_aria = aria_after
                    else:
                        # SECOND: Try click
                        print(f"    Hover didn't work, clicking...")
                        clicked = await dynamic_explorer.click_button(
                            page, tab['text'], prefer_role=tab['role']
                        )
                        if not clicked:
                            print(f"    ⚠️ Could not click")
                            continue
                        await page.wait_for_timeout(300)
                        tab_aria = await page.locator('body').aria_snapshot()
                        print(f"    ✅ Clicked")
                    
                    # Show content under tab
                    lines = tab_aria.split('\n')
                    start_idx = 0
                    for i, line in enumerate(lines):
                        if f'"{tab["text"]}"' in line:
                            start_idx = i + 1
                            break
                    
                    content_lines = lines[start_idx:start_idx + 30]
                    print(f"\n    ARIA CONTENT:")
                    print("    " + "\n    ".join(content_lines[:20]))
                    
                except Exception as e:
                    print(f"    ⚠️ Error: {e}")
                    
        except Exception as e:
            import traceback
            print(f"  ⚠️ Error: {e}")
            traceback.print_exc()

print(f"\n{'='*70}")
print("DONE")
print(f"{'='*70}")

# %%
# =============================================================================
# STEP 3: Full exploration using explore_all_tabs (NEW UNIFIED APPROACH)
# Automatically detects BULK vs DFS mode per tab
# Handles both tabs and no-tabs cases
# =============================================================================
reload_modules()
from scraper.navigation.llm_popup_dismiss import dismiss_popups_with_llm
import importlib
import scraper.navigation.llm_popup_dismiss as popup_module
importlib.reload(popup_module)
from scraper.navigation.llm_popup_dismiss import dismiss_popups_with_llm

BRANDS = [
    "entire_studios",
    "prod_bldg",
    "named_collective",
    "alexander_mcqueen",
    "balenciaga",
    "zalando_kids",
    "uniqlo",
    "aelfric_eden",
    "eckhaus_latta",
    "axel_arigato",
]

# Select ONE brand to test (full exploration can be slow)
TEST_BRAND = BRANDS[2]  # Change this to test different brands

# Check if CACHED_RESULTS exists
if 'CACHED_RESULTS' not in dir():
    print("❌ CACHED_RESULTS not defined. Run STEP 1 first.")
elif TEST_BRAND not in CACHED_RESULTS:
    print(f"❌ '{TEST_BRAND}' not in CACHED_RESULTS.")
    print(f"   Available brands: {list(CACHED_RESULTS.keys())}")
else:
    cached = CACHED_RESULTS[TEST_BRAND]
    status = cached['status']
    
    # Get tabs (may be None for no_tabs status)
    tabs = cached.get('tabs') or []
    url = cached.get('url') or TEST_BRANDS[TEST_BRAND]
    
    print(f"{'='*70}")
    print(f"FULL EXPLORATION: {TEST_BRAND}")
    print(f"Status: {status}")
    if tabs:
        print(f"Tabs: {[t['text'] for t in tabs]}")
    else:
        print(f"Tabs: None (will explore menu directly)")
    print(f"{'='*70}")
    
    try:
        # Navigate and setup
        await page.goto(url, wait_until="domcontentloaded")
        await page.wait_for_timeout(1500)
        
        await dismiss_popups_with_llm(page, max_attempts=2)
        
        # Open menu
        menu_result = await dynamic_explorer.open_menu_and_capture(page)
        if not menu_result['opened']:
            print("❌ Could not open menu")
        else:
            # IMPORTANT: menu_is_open=True to avoid closing the menu!
            await dismiss_popups_with_llm(page, max_attempts=1, menu_is_open=True)
            
            # Run full exploration (handles both tabs and no-tabs)
            results = await dynamic_explorer.explore_all_tabs(
                page=page,
                tabs=tabs,  # Empty list if no tabs
                base_url=url,
                menu_result=menu_result
            )
            
            # Print full results (no truncation)
            print(f"\n{'='*70}")
            print("RESULTS")
            print(f"{'='*70}")
            
            for tab_name, tab_result in results['tabs'].items():
                mode = tab_result.get('mode', 'unknown')
                cats = tab_result.get('categories', {})
                print(f"\n[{tab_name}] Mode: {mode}, Categories: {len(cats)}")
                for name, cat_url in cats.items():
                    print(f"    {name} → {cat_url}")
            
            print(f"\n{'='*70}")
            print(f"TOTAL: {len(results['all_categories'])} categories")
            print(f"LLM Usage: {results['llm_usage']}")
            
    except Exception as e:
        import traceback
        print(f"❌ Error: {e}")
        traceback.print_exc()

# %%
# Check LLM usage
print(f"Total LLM usage: {dynamic_explorer._llm_usage}")

# %%
# Close browser when done
await browser.close()
await playwright.stop()
print("Browser closed.")

# %% [markdown]
# # =============================================================================
# # STEP-BY-STEP EXPLORER - Debug one interaction at a time
# # =============================================================================

# %%
# RELOAD: Reload modules without restarting browser
import importlib
import sys

# Force remove all cached modules to pick up changes
modules_to_clear = [
    'scraper.navigation.dynamic_explorer',
    'scraper.navigation.llm_popup_dismiss', 
    'scraper.navigation.step_explorer',
    'scraper.navigation.extraction.links',
    'scraper.navigation.extraction.nav_elements',  # ADDED - was missing!
    'scraper.navigation.aria.elements',
    'scraper.navigation.aria.diff',
    'scraper.navigation.menu.context',
    'scraper.navigation.llm.classification',
    'scraper.navigation.llm.client',
    'dynamic_explorer',
    'step_explorer'
]
for mod in modules_to_clear:
    if mod in sys.modules:
        del sys.modules[mod]

# Fresh import
from step_explorer import NavExplorer

# Create new explorer with SAME page (browser stays open)
explorer = NavExplorer(page)
print("Modules reloaded. Run explorer.setup(URL) to initialize.")

# SETUP: Create step explorer
import importlib
import sys

# Force reload of all navigation modules
modules_to_clear = [
    'scraper.navigation.dynamic_explorer',
    'scraper.navigation.step_explorer',
    'scraper.navigation.extraction.links',
    'scraper.navigation.extraction.nav_elements',  # ADDED - was missing!
    'scraper.navigation.aria.elements',
    'scraper.navigation.aria.diff',
    'scraper.navigation.menu.context',
    'scraper.navigation.llm.classification',
    'scraper.navigation.llm.client',
    'dynamic_explorer',
    'step_explorer'
]
for mod in modules_to_clear:
    if mod in sys.modules:
        del sys.modules[mod]

# Fresh import
from step_explorer import NavExplorer

TEST_BRANDS = {
    "entire_studios": "https://www.entirestudios.com",
    "prod_bldg": "https://prod.net",
    "named_collective": "https://namedcollective.com",
    "alexander_mcqueen": "https://www.alexandermcqueen.com",
    "balenciaga": "https://www.balenciaga.com",
    "zalando_kids": "https://www.zalando.de/kinder-home/",
    "uniqlo": "https://www.uniqlo.com",
    "aelfric_eden": "https://www.aelfriceden.com",
    "eckhaus_latta": "https://www.eckhauslatta.com",
    "axel_arigato": "https://www.axelarigato.com",
}

# Choose URL to test
URL = TEST_BRANDS["axel_arigato"]

explorer = NavExplorer(page)
result = await explorer.setup(URL)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 25
#      22         del sys.modules[mod]
#      24 # Fresh import
# ---> 25 from step_explorer import NavExplorer
#      27 # Create new explorer with SAME page (browser stays open)
#      28 explorer = NavExplorer(page)
#
# File ~/Code/fashion_archive/backend/scraper/navigation/step_explorer.py:16
#      13 from playwright.async_api import Page
#      14 from pydantic import BaseModel, Field
# ---> 16 from scraper.navigation.extraction.nav_elements import extract_and_filter_nav_elements
#      17 from scraper.navigation.llm.client import get_llm_handler
#      18 from scraper.navigation.dynamic_explorer import (
#      19     open_menu_and_capture,
#      20     click_button,
#      21     identify_tabs_with_llm,
#      22     find_tabs_in_dom,
#      23 )
#
# ModuleNotFoundError: No module named 'scraper'

# %%
# RUN ONE STEP (re-run this cell to retry same item)
result = await explorer.step()
print(f"\nAction: {result.action}")
print(f"Item: {' > '.join(result.item_path)}")
print(f"Success: {result.success}")
if result.error:
    print(f"Error: {result.error}")
if result.links_found:
    print(f"Links found: {list(result.links_found.keys())}")
print(f"Children added: {result.children_added}")
# Out:
# [STEP] Men (button)
#   Stack: 1 remaining
#   [ARIA] WARNING: No menu container found, using body
#   [ARIA BEFORE] 15788 chars, 523 lines
#     - main:
#       - button "FREE RETURNS":
#         - link "FREE RETURNS":
#           - /url: /assistance?group=returns-and-exchanges&faq=what-is-your-return-policy
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - navigation
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - searchbox "Search"
#       - button "Close search":
#         - img
#       - text: Search
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - button "Men"
#       - button "Women"
#       - button "Shoes":
#         - button "Shoes":
#           - text: Shoes
#           - img
#       - button "Clothing":
#         - button "Clothing":
#           - text: Clothing
#           - img
#       - button "Accessories":
#         - button "Accessories":
#           - text: Accessories
#           - img
#       - link "New Arrivals":
#         - /url: /women/new-arrivals
#         - button "New Arrivals"
#       - link "Top Sellers":
#         - /url: /women/top-sellers
#         - button "Top Sellers"
#       - link "SS26 EDITNEW":
#         - /url: /women-ss26-edit
#         - button "SS26 EDITNEW"
#       - link "View all women":
#         - /url: /women
#         - button "View all women"
#       - link "Brown suede sneakers with white laces on a textured beige surface. The soles are black with a distinct pattern. DAZE RUNNER SHOP NOW":
#         - /url: /women/footwear/daze
#         - img "Brown suede sneakers with white laces on a textured beige surface. The soles are black with a distinct pattern."
#         - text: DAZE RUNNER
#         - img
#         - text: SHOP NOW
#       - link "Customer Support":
#         - /url: /contact
#         - button "Customer Support":
#           - text: Customer Support
#           - img
#       - button "Language / en English":
#         - text: Language / en
#         - img
#         - combobox:
#           - option "English" [selected]
#           - option "French"
#           - option "German"
#       - button "Shipping To / United States of America United States of America":
#         - text: Shipping To / United States of America
#         - img
#         - combobox:
#           - option "Select Country" [disabled]
#           - option "Albania"
#           - option "Andorra"
#           - option "Anguilla"
#           - option "Argentina"
#           - option "Aruba"
#           - option "Australia"
#           - option "Austria"
#           - option "Azerbaijan"
#           - option "Bahamas"
#           - option "Bahrain"
#           - option "Bangladesh"
#           - option "Barbados"
#           - option "Belgium"
#           - option "Belize"
#           - option "Bermuda"
#           - option "Bhutan"
#           - option "Bolivia"
#           - option "Bosnia and Herzegovina"
#           - option "Brunei Darussalam"
#           - option "Bulgaria"
#           - option "Cambodia"
#           - option "Canada"
#           - option "Cayman Islands"
#           - option "Chile"
#           - option "China Mainland"
#           - option "Colombia"
#           - option "Costa Rica"
sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f3535004
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD":
#         - /url: /men/footwear/clean-90/cap-toe-sneaker-f4273001
#         - img "Clean 90 Cap-Toe Sneaker"
#         - paragraph: Clean 90 Cap-Toe Sneaker
#         - text: 325 USD
#       - button:
#         - img
#       - link "Clay Sneaker Clay Sneaker 365 USD":
#         - /url: /men/footwear/clay/clay-sneaker-f2538004
#         - img "Clay Sneaker"
#         - paragraph: Clay Sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD":
#         - /url: /men/footwear/orbit/orbit-vintage-sneaker-f3216003
#         - img "Orbit Vintage Sneaker"
#         - paragraph: Orbit Vintage Sneaker
#         - text: 350 USD
#       - img "Stack of three stylish sneakers in dark gray, beige, and cream with orange accents against a plain white background."
#       - 'link "ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT."':
#         - /url: /men/footwear/orbit
#         - paragraph: "ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT."
#       - link:
#         - /url: /men/footwear/orbit
#       - link "SHOP MEN":
#         - /url: /men/footwear/orbit
#         - img
#         - text: SHOP MEN
#       - link:
#         - /url: /men/footwear/orbit
#       - link:
#         - /url: /men/footwear/orbit
#       - link "A pair of beige and orange sneakers, with one showing the side profile and the other displaying the gum sole, on a light gray background.":
#         - /url: /men/new-arrivals
#         - img "A pair of beige and orange sneakers, with one showing the side profile and the other displaying the gum sole, on a light gray background."
#       - text: NEW ARRIVALS
#       - link "DISCOVER MEN":
#         - /url: /men/new-arrivals
#         - img
#         - text: DISCOVER MEN
#       - link "DISCOVER WOMEN":
#         - /url: /women/new-arrivals
#         - img
#         - text: DISCOVER WOMEN
#       - link "DJ wearing headphones, adjusting the mixer at a booth, focused under stage lighting, with people and cups visible in the dim background.":
#         - /url: https://axelarigato.com/events
#         - img "DJ wearing headphones, adjusting the mixer at a booth, focused under stage lighting, with people and cups visible in the dim background."
#       - text: COMMUNITY
#       - link "DISCOVER":
#         - /url: https://axelarigato.com/events
#         - img
#         - text: DISCOVER
#       - link "Two neatly coiled lavender shoelaces on a white background, showcasing their woven texture and soft pastel color.":
#         - /url: /extra-laces-men
#         - img "Two neatly coiled lavender shoelaces on a white background, showcasing their woven texture and soft pastel color."
#       - text: EXTRA LACES
#       - link "DISCOVER MEN":
#         - /url: /extra-laces-men
#         - img
#         - text: DISCOVER MEN
#       - link "DISCOVER WOMEN":
#         - /url: /extra-laces-women
#         - img
#         - text: DISCOVER WOMEN
#       - link "Street corner with a brick building housing the Axel Arigato store, displaying modern interiors through large windows. Traffic light and crosswalk visible.":
#         - /url: /stores
#         - img "Street corner with a brick building housing the Axel Arigato store, displaying modern interiors through large windows. Traffic light and crosswalk visible."
#       - text: FIND A STORE
#       - link "DISCOVER":
#         - /url: /stores
#         - img
#         - text: DISCOVER
#     - paragraph: Subscribe to our newsletter for exclusive updates on drops, sales & events.
#     - textbox "JOIN THE COMMUNITY"
#     - text: JOIN THE COMMUNITY
#     - contentinfo:
#       - button "Company":
#         - text: Company
#         - img
#       - button "Customer Support":
#         - text: Customer Support
#         - img
#       - button "Community":
#         - text: Community
#         - img
#       - button "Language / en":
#         - text: Language / en
#         - img
#       - button "Shipping To / United States of America":
#         - text: Shipping To / United States of America
#         - img
#       - img
#     - alert
#     - img
#     - text: 1 Unblock Notifications
#     - paragraph: "Follow these instructions to allow notifications:"
#     - text: axelarigato.com
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 72 elements from ARIA:
#     [button] FREE RETURNS (url=None)
#     [link] FREE RETURNS (url=/assistance?group=returns-and-exchanges&faq=what-is-your-return-policy)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [button] Shoes (url=None)
#     [button] Shoes (url=None)
#     [button] Clothing (url=None)
#     [button] Clothing (url=None)
#     [button] Accessories (url=None)
#     [button] Accessories (url=None)
#     [link] New Arrivals (url=/women/new-arrivals)
#     [button] New Arrivals (url=None)
#     [link] Top Sellers (url=/women/top-sellers)
#     [button] Top Sellers (url=None)
#     [link] SS26 EDITNEW (url=/women-ss26-edit)
#     [button] SS26 EDITNEW (url=None)
#     [link] View all women (url=/women)
#     [button] View all women (url=None)
#     [link] Customer Support (url=/contact)
#     [button] Customer Support (url=None)
#     [button] Language / en English (url=None)
#     [link] DAZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIGN. (url=/men/footwear/daze)
#     [link] SHOP MEN (url=/men/footwear/daze)
#     [link] SHOP WOMEN (url=/women/footwear/daze)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3694001)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3617001)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3683002)
#     [link] Eris Sneaker Eris Sneaker 450 USD (url=/men/footwear/eris/eris-sneaker-f3567002)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f4031001)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3644003)
#     [link] Eris Sneaker Eris Sneaker 465 USD (url=/men/footwear/eris/eris-sneaker-f3911001)
#     [link] Squish Sneaker Squish Sneaker 365 USD (url=/men/footwear/squish/squish-sneaker-f3654002)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3644002)
#     [link] Eris Sneaker Eris Sneaker 465 USD (url=/men/footwear/eris/eris-sneaker-f3911003)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3617003)
#     [link] Grain Sneaker Grain Sneaker 495 USD (url=/men/footwear/grain/grain-sneaker-f3928002)
#     [link] DICE T-TOE: ICONIC. BACK IN STOCK. (url=/men/footwear/dice)
#     [link] SHOP MEN (url=/men/footwear/dice)
#     [link] DICE T-TOE PONY: A BOLD NEW FEEL (url=/women/footwear/dice)
#     [link] SHOP WOMEN (url=/women/footwear/dice)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [link] Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD (url=/men/footwear/orbit/orbit-vintage-sneaker-f3216001)
#     [link] Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD (url=/men/footwear/dice/dice-t-toe-sneaker-f3032001)
#     [link] Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD (url=/men/footwear/area/area-lo-sneaker-f2279001)
#     [link] Clean 90 Sneaker Clean 90 Sneaker 325 USD (url=/men/footwear/clean-90/clean-90-28102)
#     [link] Atlas Sneaker Atlas Sneaker 345 USD (url=/men/footwear/atlas/atlas-sneaker-f3600002)
#     [link] Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD (url=/men/footwear/dice/dice-t-toe-sneaker-f3625003)
#     [link] Genesis Neo Bird Runner Genesis Neo Bird Runner 345 USD (url=/men/footwear/genesis/genesis-neo-bird-runner-f3572001)
#     [link] Clay Sneaker Clay Sneaker 365 USD (url=/men/footwear/clay/clay-sneaker-f3559001)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3535004)
#     [link] Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD (url=/men/footwear/clean-90/cap-toe-sneaker-f4273001)
#     [link] Clay Sneaker Clay Sneaker 365 USD (url=/men/footwear/clay/clay-sneaker-f2538004)
#     [link] Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD (url=/men/footwear/orbit/orbit-vintage-sneaker-f3216003)
#     [link] ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT. (url=/men/footwear/orbit)
#     [link] SHOP MEN (url=/men/footwear/orbit)
#     [link] DISCOVER MEN (url=/men/new-arrivals)
#     [link] DISCOVER WOMEN (url=/women/new-arrivals)
#     [link] DISCOVER (url=https://axelarigato.com/events)
#     [link] DISCOVER MEN (url=/extra-laces-men)
#     [link] DISCOVER WOMEN (url=/extra-laces-women)
#     [link] DISCOVER (url=/stores)
#     [button] Company (url=None)
#     [button] Customer Support (url=None)
#     [button] Community (url=None)
#     [button] Language / en (url=None)
#     [button] Shipping To / United States of America (url=None)
#   [EXTRACT] CSS groups: 9
#     col-span-7 (3 items):
#       - FREE RETURNS
#       - DISCOVER
#       - DISCOVER
#     col-span-4 (6 items):
#       - Toggle mobile wishlist
#       - Toggle mobile wishlist
#       - Toggle mobile wishlist
#       - Men
#       - Men
#       - Men
#     scrollbar-hide (3 items):
#       - Women
#       - Women
#       - Women
#     w-full (10 items):
#       - Shoes
#       - Shoes
#       - Clothing
#       - Clothing
#       - Accessories
#       - Accessories
#       - DAZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIGN.
#       - DICE T-TOE: ICONIC. BACK IN STOCK.
#       - DICE T-TOE PONY: A BOLD NEW FEEL
#       - ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT.
#     div (7 items):
#       - New Arrivals
#       - Top Sellers
#       - SS26 EDITNEW
#       - View all women
#       - Customer Support
#       - Company
#       - Community
#     a (6 items):
#       - New Arrivals
#       - Top Sellers
#       - SS26 EDITNEW
#       - View all women
#       - Customer Support
#       - Customer Support
#     relative (7 items):
#       - Language / en English
#       - SHOP MEN
#       - SHOP WOMEN
#       - SHOP MEN
#       - SHOP WOMEN
#       - SHOP MEN
#       - Language / en
#     group (24 items):
#       - Slow Runner Slow Runner 385 USD
#       - Daze Runner Daze Runner 330 USD
#       - Daze Runner Daze Runner 330 USD
#       - Eris Sneaker Eris Sneaker 450 USD
#       - Daze Runner Daze Runner 330 USD
#       - Slow Runner Slow Runner 385 USD
#       - Eris Sneaker Eris Sneaker 465 USD
#       - Squish Sneaker Squish Sneaker 365 USD
#       - Slow Runner Slow Runner 385 USD
#       - Eris Sneaker Eris Sneaker 465 USD
#       - Daze Runner Daze Runner 330 USD
#       - Grain Sneaker Grain Sneaker 495 USD
#       - Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD
#       - Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD
#       - Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD
#       - Clean 90 Sneaker Clean 90 Sneaker 325 USD
#       - Atlas Sneaker Atlas Sneaker 345 USD
#       - Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD
#       - Genesis Neo Bird Runner Genesis Neo Bird Runner 345 USD
#       - Clay Sneaker Clay Sneaker 365 USD
#       - Daze Runner Daze Runner 330 USD
#       - Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD
#       - Clay Sneaker Clay Sneaker 365 USD
#       - Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD
#     flex (4 items):
#       - DISCOVER MEN
#       - DISCOVER WOMEN
#       - DISCOVER MEN
#       - DISCOVER WOMEN
#     LLM exclusion response: {"exclude": [1, 2, 5, 6, 7], "reason": "Group 1 has policies, Group 2 has mobile UI toggles, Groups 5-6 have support/company links, Group 7 has language selector and redundant shop links"}
#     LLM reason: Group 1 has policies, Group 2 has mobile UI toggles, Groups 5-6 have support/company links, Group 7 has language selector and redundant shop links
#   [EXTRACT] LLM excluded groups: {'div', 'col-span-4', 'relative', 'col-span-7', 'a'}
#   [EXTRACT] excluded_groups={'div', 'col-span-4', 'relative', 'col-span-7', 'a'}
#   [EXTRACT] Excluded: ['FREE RETURNS (class=col-span-7)', 'Toggle mobile wishlist (class=col-span-4)', 'Toggle mobile wishlist (class=col-span-4)', 'Toggle mobile wishlist (class=col-span-4)', 'Men (class=col-span-4)', 'New Arrivals (class=div)', 'New Arrivals (class=a)', 'Top Sellers (class=div)', 'Top Sellers (class=a)', 'SS26 EDITNEW (class=div)', 'SS26 EDITNEW (class=a)', 'View all women (class=div)', 'View all women (class=a)', 'Customer Support (class=div)', 'Customer Support (class=a)', 'Language / en English (class=relative)', 'SHOP MEN (class=relative)', 'SHOP WOMEN (class=relative)', 'Men (class=col-span-4)', 'SHOP MEN (class=relative)', 'SHOP WOMEN (class=relative)', 'Men (class=col-span-4)', 'SHOP MEN (class=relative)', 'DISCOVER (class=col-span-7)', 'DISCOVER (class=col-span-7)', 'Company (class=div)', 'Customer Support (class=a)', 'Community (class=div)', 'Language / en (class=relative)']
#   [EXTRACT] After CSS filter: 43 elements
#   [CLICK] Men
#         [CLICK-DETAIL] Strict role search: only trying 'button'
#         [CLICK-DETAIL] button exact=True: 3 matches
#         [CLICK-DEBUG] WARNING: Found 3 elements for 'Men' as button
#         [CLICK-DETAIL] Found 'Men' as button (#1 of 3, visible)
#   [EXPAND] Content expanded in place (no back button)
#   [ARIA] WARNING: No menu container found, using body
#   [ARIA AFTER] 15860 chars, 523 lines
#     - main:
#       - button "FREE EXPRESS DELIVERY":
#         - link "FREE EXPRESS DELIVERY":
#           - /url: /assistance?group=shipping-and-delivery&faq=which-delivery-services-do-you-offer-how-much-do-they-cost-and-how-long-do-they-take
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - navigation
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - searchbox "Search"
#       - button "Close search":
#         - img
#       - text: Search
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - button "Men"
#       - button "Women"
#       - button "Shoes":
#         - button "Shoes":
#           - text: Shoes
#           - img
#       - button "Clothing":
#         - button "Clothing":
#           - text: Clothing
#           - img
#       - button "Accessories":
#         - button "Accessories":
#           - text: Accessories
#           - img
#       - link "New Arrivals":
#         - /url: /men/new-arrivals
#         - button "New Arrivals"
#       - link "Top Sellers":
#         - /url: /men/top-sellers
#         - button "Top Sellers"
#       - link "SS26 EDITNEW":
#         - /url: /men-ss26-edit
#         - button "SS26 EDITNEW"
#       - link "View all men":
#         - /url: /men
#         - button "View all men"
#       - link "A pair of stylish beige suede sneakers with white laces and textured brown soles displayed on a light woven surface. DAZE RUNNER SHOP NOW":
#         - /url: /men/footwear/daze
#         - img "A pair of stylish beige suede sneakers with white laces and textured brown soles displayed on a light woven surface."
#         - text: DAZE RUNNER
#         - img
#         - text: SHOP NOW
#       - link "Customer Support":
#         - /url: /contact
#         - button "Customer Support":
#           - text: Customer Support
#           - img
#       - button "Language / en English":
#         - text: Language / en
#         - img
#         - combobox:
#           - option "English" [selected]
#           - option "French"
#           - option "German"
#       - button "Shipping To / United States of America United States of America":
#         - text: Shipping To / United States of America
#         - img
#         - combobox:
#           - option "Select Country" [disabled]
#           - option "Albania"
#           - option "Andorra"
#           - option "Anguilla"
#           - option "Argentina"
AZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIGN."':
#         - /url: /men/footwear/daze
#         - paragraph: "DAZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIGN."
#       - link:
#         - /url: /men/footwear/daze
#       - link "SHOP MEN":
#         - /url: /men/footwear/daze
#         - img
#         - text: SHOP MEN
#       - link "SHOP WOMEN":
#         - /url: /women/footwear/daze
#         - img
#         - text: SHOP WOMEN
#       - link:
#         - /url: /men/footwear/daze
#       - link:
#         - /url: /men/footwear/daze
#       - text: NEWNESS
#       - button "Men" [disabled]
#       - button "Women"
#       - button:
#         - img
#       - link "Slow Runner Slow Runner 385 USD":
#         - /url: /men/footwear/slow/slow-runner-f3694001
#         - img "Slow Runner"
#         - paragraph: Slow Runner
#         - text: 385 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f3617001
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f3683002
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Eris Sneaker Eris Sneaker 450 USD":
#         - /url: /men/footwear/eris/eris-sneaker-f3567002
#         - img "Eris Sneaker"
#         - paragraph: Eris Sneaker
#         - text: 450 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f4031001
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Slow Runner Slow Runner 385 USD":
#         - /url: /men/footwear/slow/slow-runner-f3644003
#         - img "Slow Runner"
#         - paragraph: Slow Runner
#         - text: 385 USD
#       - button:
#         - img
#       - link "Eris Sneaker Eris Sneaker 465 USD":
#         - /url: /men/footwear/eris/eris-sneaker-f3911001
#         - img "Eris Sneaker"
#         - paragraph: Eris Sneaker
#         - text: 465 USD
#       - button:
#         - img
#       - link "Squish Sneaker Squish Sneaker 365 USD":
#         - /url: /men/footwear/squish/squish-sneaker-f3654002
#         - img "Squish Sneaker"
#         - paragraph: Squish Sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Slow Runner Slow Runner 385 USD":
#         - /url: /men/footwear/slow/slow-runner-f3644002
#         - img "Slow Runner"
#         - paragraph: Slow Runner
#         - text: 385 USD
#       - button:
#         - img
#       - link "Eris Sneaker Eris Sneaker 465 USD":
#         - /url: /men/footwear/eris/eris-sneaker-f3911003
#         - img "Eris Sneaker"
#         - paragraph: Eris Sneaker
#         - text: 465 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f3617003
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Grain Sneaker Grain Sneaker 495 USD":
#         - /url: /men/footwear/grain/grain-sneaker-f3928002
#         - img "Grain Sneaker"
#         - paragraph: Grain Sneaker
#         - text: 495 USD
#       - img "Black Arcato sneaker with white laces and gray sole, placed on a light-checkered surface."
#       - 'link "DICE T-TOE: ICONIC. BACK IN STOCK."':
#         - /url: /men/footwear/dice
#         - paragraph: "DICE T-TOE: ICONIC. BACK IN STOCK."
#       - link:
#         - /url: /men/footwear/dice
#       - link "SHOP MEN":
#         - /url: /men/footwear/dice
#         - img
#         - text: SHOP MEN
#       - link:
#         - /url: /men/footwear/dice
#       - link:
#         - /url: /men/footwear/dice
#       - img "A stylish sneaker with a brown and white pattern, cream laces, and a brown sole, viewed from the front against a plain background."
#       - 'link "DICE T-TOE PONY: A BOLD NEW FEEL"':
#         - /url: /women/footwear/dice
#         - paragraph: "DICE T-TOE PONY: A BOLD NEW FEEL"
#       - link:
#         - /url: /women/footwear/dice
#       - link "SHOP WOMEN":
#         - /url: /women/footwear/dice
#         - img
#         - text: SHOP WOMEN
#       - link:
#         - /url: /women/footwear/dice
#       - link:
#         - /url: /women/footwear/dice
#       - text: ESSENTIALS
#       - button "Men" [disabled]
#       - button "Women"
#       - button:
#         - img
#       - link "Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD":
#         - /url: /men/footwear/orbit/orbit-vintage-sneaker-f3216001
#         - img "Orbit Vintage Sneaker"
#         - paragraph: Orbit Vintage Sneaker
#         - text: 350 USD
#       - button:
#         - img
#       - link "Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD":
#         - /url: /men/footwear/dice/dice-t-toe-sneaker-f3032001
#         - img "Dice T-Toe Sneaker"
#         - paragraph: Dice T-Toe Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD":
#         - /url: /men/footwear/area/area-lo-sneaker-f2279001
#         - img "Area Lo Fluffy Sneaker"
#         - paragraph: Area Lo Fluffy Sneaker
#         - text: 420 USD
#       - button:
#         - img
#       - link "Clean 90 Sneaker Clean 90 Sneaker 325 USD":
#         - /url: /men/footwear/clean-90/clean-90-28102
#         - img "Clean 90 Sneaker"
#         - paragraph: Clean 90 Sneaker
#         - text: 325 USD
#       - button:
#         - img
#       - link "Atlas Sneaker Atlas Sneaker 345 USD":
#         - /url: /men/footwear/atlas/atlas-sneaker-f3600002
#         - img "Atlas Sneaker"
#         - paragraph: Atlas Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD":
#         - /url: /men/footwear/dice/dice-t-toe-sneaker-f3625003
#         - img "Dice T-Toe Sneaker"
#         - paragraph: Dice T-Toe Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Genesis Neo Bird Runner Genesis Neo Bird Runner 345 USD":
#         - /url: /men/footwear/genesis/genesis-neo-bird-runner-f3572001
#         - img "Genesis Neo Bird Runner"
#         - paragraph: Genesis Neo Bird Runner
#         - text: 345 USD
#       - button:
#         - img
#       - link "Clay Sneaker Clay Sneaker 365 USD":
#         - /url: /men/footwear/clay/clay-sneaker-f3559001
#         - img "Clay Sneaker"
#         - paragraph: Clay Sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f3535004
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD":
#         - /url: /men/footwear/clean-90/cap-toe-sneaker-f4273001
#         - img "Clean 90 Cap-Toe Sneaker"
#         - paragraph: Clean 90 Cap-Toe Sneaker
#         - text: 325 USD
#       - button:
#         - img
#       - link "Clay Sneaker Clay Sneaker 365 USD":
#         - /url: /men/footwear/clay/clay-sneaker-f2538004
#         - img "Clay Sneaker"
#         - paragraph: Clay Sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD":
#         - /url: /men/footwear/orbit/orbit-vintage-sneaker-f3216003
#         - img "Orbit Vintage Sneaker"
#         - paragraph: Orbit Vintage Sneaker
#         - text: 350 USD
#       - img "Stack of three stylish sneakers in dark gray, beige, and cream with orange accents against a plain white background."
#       - 'link "ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT."':
#         - /url: /men/footwear/orbit
#         - paragraph: "ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT."
#       - link:
#         - /url: /men/footwear/orbit
#       - link "SHOP MEN":
#         - /url: /men/footwear/orbit
#         - img
#         - text: SHOP MEN
#       - link:
#         - /url: /men/footwear/orbit
#       - link:
#         - /url: /men/footwear/orbit
#       - link "A pair of beige and orange sneakers, with one showing the side profile and the other displaying the gum sole, on a light gray background.":
#         - /url: /men/new-arrivals
#         - img "A pair of beige and orange sneakers, with one showing the side profile and the other displaying the gum sole, on a light gray background."
#       - text: NEW ARRIVALS
#       - link "DISCOVER MEN":
#         - /url: /men/new-arrivals
#         - img
#         - text: DISCOVER MEN
#       - link "DISCOVER WOMEN":
#         - /url: /women/new-arrivals
#         - img
#         - text: DISCOVER WOMEN
#       - link "DJ wearing headphones, adjusting the mixer at a booth, focused under stage lighting, with people and cups visible in the dim background.":
#         - /url: https://axelarigato.com/events
#         - img "DJ wearing headphones, adjusting the mixer at a booth, focused under stage lighting, with people and cups visible in the dim background."
#       - text: COMMUNITY
#       - link "DISCOVER":
#         - /url: https://axelarigato.com/events
#         - img
#         - text: DISCOVER
#       - link "Two neatly coiled lavender shoelaces on a white background, showcasing their woven texture and soft pastel color.":
#         - /url: /extra-laces-men
#         - img "Two neatly coiled lavender shoelaces on a white background, showcasing their woven texture and soft pastel color."
#       - text: EXTRA LACES
#       - link "DISCOVER MEN":
#         - /url: /extra-laces-men
#         - img
#         - text: DISCOVER MEN
#       - link "DISCOVER WOMEN":
#         - /url: /extra-laces-women
#         - img
#         - text: DISCOVER WOMEN
#       - link "Street corner with a brick building housing the Axel Arigato store, displaying modern interiors through large windows. Traffic light and crosswalk visible.":
#         - /url: /stores
#         - img "Street corner with a brick building housing the Axel Arigato store, displaying modern interiors through large windows. Traffic light and crosswalk visible."
#       - text: FIND A STORE
#       - link "DISCOVER":
#         - /url: /stores
#         - img
#         - text: DISCOVER
#     - paragraph: Subscribe to our newsletter for exclusive updates on drops, sales & events.
#     - textbox "JOIN THE COMMUNITY"
#     - text: JOIN THE COMMUNITY
#     - contentinfo:
#       - button "Company":
#         - text: Company
#         - img
#       - button "Customer Support":
#         - text: Customer Support
#         - img
#       - button "Community":
#         - text: Community
#         - img
#       - button "Language / en":
#         - text: Language / en
#         - img
#       - button "Shipping To / United States of America":
#         - text: Shipping To / United States of America
#         - img
#       - img
#     - alert
#     - img
#     - text: 1 Unblock Notifications
#     - paragraph: "Follow these instructions to allow notifications:"
#     - text: axelarigato.com
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 72 elements from ARIA:
#     [button] FREE EXPRESS DELIVERY (url=None)
#     [link] FREE EXPRESS DELIVERY (url=/assistance?group=shipping-and-delivery&faq=which-delivery-services-do-you-offer-how-much-do-they-cost-and-how-long-do-they-take)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [button] Shoes (url=None)
#     [button] Shoes (url=None)
#     [button] Clothing (url=None)
#     [button] Clothing (url=None)
#     [button] Accessories (url=None)
#     [button] Accessories (url=None)
#     [link] New Arrivals (url=/men/new-arrivals)
#     [button] New Arrivals (url=None)
#     [link] Top Sellers (url=/men/top-sellers)
#     [button] Top Sellers (url=None)
#     [link] SS26 EDITNEW (url=/men-ss26-edit)
#     [button] SS26 EDITNEW (url=None)
#     [link] View all men (url=/men)
#     [button] View all men (url=None)
#     [link] Customer Support (url=/contact)
#     [button] Customer Support (url=None)
#     [button] Language / en English (url=None)
#     [link] DAZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIGN. (url=/men/footwear/daze)
#     [link] SHOP MEN (url=/men/footwear/daze)
#     [link] SHOP WOMEN (url=/women/footwear/daze)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3694001)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3617001)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3683002)
#     [link] Eris Sneaker Eris Sneaker 450 USD (url=/men/footwear/eris/eris-sneaker-f3567002)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f4031001)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3644003)
#     [link] Eris Sneaker Eris Sneaker 465 USD (url=/men/footwear/eris/eris-sneaker-f3911001)
#     [link] Squish Sneaker Squish Sneaker 365 USD (url=/men/footwear/squish/squish-sneaker-f3654002)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3644002)
#     [link] Eris Sneaker Eris Sneaker 465 USD (url=/men/footwear/eris/eris-sneaker-f3911003)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3617003)
#     [link] Grain Sneaker Grain Sneaker 495 USD (url=/men/footwear/grain/grain-sneaker-f3928002)
#     [link] DICE T-TOE: ICONIC. BACK IN STOCK. (url=/men/footwear/dice)
#     [link] SHOP MEN (url=/men/footwear/dice)
#     [link] DICE T-TOE PONY: A BOLD NEW FEEL (url=/women/footwear/dice)
#     [link] SHOP WOMEN (url=/women/footwear/dice)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [link] Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD (url=/men/footwear/orbit/orbit-vintage-sneaker-f3216001)
#     [link] Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD (url=/men/footwear/dice/dice-t-toe-sneaker-f3032001)
#     [link] Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD (url=/men/footwear/area/area-lo-sneaker-f2279001)
#     [link] Clean 90 Sneaker Clean 90 Sneaker 325 USD (url=/men/footwear/clean-90/clean-90-28102)
#     [link] Atlas Sneaker Atlas Sneaker 345 USD (url=/men/footwear/atlas/atlas-sneaker-f3600002)
#     [link] Dice T-Toe Sneaker Dice T-Toe Sneaker 345 US
orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD
#     flex (6 items):
#       - DISCOVER MEN
#       - DISCOVER WOMEN
#       - DISCOVER
#       - DISCOVER MEN
#       - DISCOVER WOMEN
#       - DISCOVER
#     LLM exclusion response: {"exclude": [1, 4, 5, 6, 8], "reason": "Group 1 has wishlist toggles (utility), Groups 4&5 have customer support/company links (utility), Group 6 has language selector and generic shop links (utility), Group 8 has generic discover links (utility). Groups 2, 3, 7 contain product categories and actual products."}
#     LLM reason: Group 1 has wishlist toggles (utility), Groups 4&5 have customer support/company links (utility), Group 6 has language selector and generic shop links (utility), Group 8 has generic discover links (utility). Groups 2, 3, 7 contain product categories and actual products.
#   [EXTRACT] LLM excluded groups: {'div', 'flex', 'col-span-4', 'relative', 'a'}
#   [EXTRACT] excluded_groups={'div', 'flex', 'col-span-4', 'relative', 'a'}
#   [EXTRACT] Excluded: ['Toggle mobile wishlist (class=col-span-4)', 'Toggle mobile wishlist (class=col-span-4)', 'Toggle mobile wishlist (class=col-span-4)', 'Men (class=col-span-4)', 'New Arrivals (class=div)', 'New Arrivals (class=a)', 'Top Sellers (class=div)', 'Top Sellers (class=a)', 'SS26 EDITNEW (class=div)', 'SS26 EDITNEW (class=a)', 'View all men (class=div)', 'View all men (class=a)', 'Customer Support (class=div)', 'Customer Support (class=a)', 'Language / en English (class=relative)', 'SHOP MEN (class=relative)', 'SHOP WOMEN (class=relative)', 'Men (class=col-span-4)', 'SHOP MEN (class=relative)', 'SHOP WOMEN (class=relative)', 'Men (class=col-span-4)', 'SHOP MEN (class=relative)', 'DISCOVER MEN (class=flex)', 'DISCOVER WOMEN (class=flex)', 'DISCOVER (class=flex)', 'DISCOVER MEN (class=flex)', 'DISCOVER WOMEN (class=flex)', 'DISCOVER (class=flex)', 'Company (class=div)', 'Customer Support (class=a)', 'Community (class=div)', 'Language / en (class=relative)']
#   [EXTRACT] After CSS filter: 40 elements
#   [IN-PLACE] Using context-based diff (name + parent/nearby_link)
#   [DIFF] 2 new elements (by context):
#     [button] FREE EXPRESS DELIVERY (idx:?, near:None)
#     [link] FREE EXPRESS DELIVERY (idx:?, near:None)
#   [NAV] Link: FREE EXPRESS DELIVERY
#   [NAV] Expandable: FREE EXPRESS DELIVERY (has children, skipped)
#   [NAV] Total: 1 links added, 0 expandables queued
#   [TREE] Total categories: 1
#   [BACK] Fallback: 84 icon buttons, 40 candidates
#     [LLM] Back button identification: index=12
#   [BACK] LLM identified back button
#   [STACK] Added 0 (LIFO - last added = next to pop)
#   [STACK] (1 items, top first):
#     → Women
#   [BACK] Going back 1 level(s) to reach 'Women'
#     [BACK] Clicked stored element
#
# Action: click
# Item: Men
# Success: True
# Links found: ['FREE EXPRESS DELIVERY']
# Children added: 0

# %%
# RUN MULTIPLE STEPS
for i in range(37):  # adjust number as needed
    if explorer.done():
        print("Done!")
        break
    result = await explorer.step()
    print(f"{i+1}. {result.item_name}: {len(result.links_found)} links, {result.children_added} children")

explorer.show_state()
# Out:
# [STEP] Women (button)
#   Stack: 0 remaining
#   [ARIA] WARNING: No menu container found, using body
#   [ARIA BEFORE] 15761 chars, 524 lines
#     - main:
#       - button "DISCOVER THE SS26 EDIT":
#         - link "DISCOVER THE SS26 EDIT":
#           - /url: /men-ss26-edit
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - navigation
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - searchbox "Search"
#       - button "Close search":
#         - img
#       - text: Search
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - button "Men"
#       - button "Women"
#       - button "Shoes":
#         - button "Shoes":
#           - text: Shoes
#           - img
#       - button "Clothing":
#         - button "Clothing":
#           - text: Clothing
#           - img
#       - button "Accessories":
#         - button "Accessories":
#           - text: Accessories
#           - img
#       - link "New Arrivals":
#         - /url: /women/new-arrivals
#         - button "New Arrivals"
#       - link "Top Sellers":
#         - /url: /women/top-sellers
#         - button "Top Sellers"
#       - link "SS26 EDITNEW":
#         - /url: /women-ss26-edit
#         - button "SS26 EDITNEW"
#       - link "View all women":
#         - /url: /women
#         - button "View all women"
#       - link "Brown suede sneakers with white laces on a textured beige surface. The soles are black with a distinct pattern. DAZE RUNNER SHOP NOW":
#         - /url: /women/footwear/daze
#         - img "Brown suede sneakers with white laces on a textured beige surface. The soles are black with a distinct pattern."
#         - text: DAZE RUNNER
#         - img
#         - text: SHOP NOW
#       - link "Customer Support":
#         - /url: /contact
#         - button "Customer Support":
#           - text: Customer Support
#           - img
#       - button "Language / en English":
#         - text: Language / en
#         - img
#         - combobox:
#           - option "English" [selected]
#           - option "French"
#           - option "German"
#       - button "Shipping To / United States of America United States of America":
#         - text: Shipping To / United States of America
#         - img
#         - combobox:
#           - option "Select Country" [disabled]
#           - option "Albania"
#           - option "Andorra"
#           - option "Anguilla"
#           - option "Argentina"
#           - option "Aruba"
#           - option "Australia"
#           - option "Austria"
#           - option "Azerbaijan"
#           - option "Bahamas"
#           - option "Bahrain"
#           - option "Bangladesh"
#           - option "Barbados"
#           - option "Belgium"
#           - option "Belize"
#           - option "Bermuda"
#           - option "Bhutan"
#           - option "Bolivia"
#           - option "Bosnia and Herzegovina"
#           - option "Brunei Darussalam"
#           - option "Bulgaria"
#           - option "Cambodia"
#           - option "Canada"
#           - option "Cayman Islands"
#           - option "Chile"
#           - option "China Mainland"
#           - option "Colombia"
#           - option "Costa Rica"
#           - option "Croatia"
#           - option "Cyprus"
#           - option "Czech Republic"
#           - option "Denmark"
#           - option "Dominica"
#           - option "Dominican Republic"
#           - option "Ecuador"
#           - option "Egypt"
#           - option "El Salvador"
#           - option "Estonia"
#           - option "Finland"
#           - option "France"
#           - option "French Guiana"
#           - option "French Polynesia"
#           - option "Germany"
#           - option "Gibraltar"
#           - option "Greece"
#           - option "Greenland"
#           - option "Grenada"
#           - option "Guadeloupe"
#           - option "Guernsey"
#           - option "Holy See (Vatican City State)"
#           - option "Honduras"
#           - option "Hong Kong"
#           - option "Hungary"
#           - option "Iceland"
#           - option "India"
#           - option "Indonesia"
#           - option "Ireland"
#           - option "Israel"
#           - option "Italy"
#           - option "Jamaica"
#           - option "Japan"
#           - option "Jersey"
#           - option "Jordan"
#           - option "Kazakhstan"
#           - option "Kosovo"
#           - option "Kuwait"
#           - option "Lao People's Democratic Republic"
#           - option "Latvia"
#           - option "Libya"
#           - option "Liechtenstein"
#         - text: SHOP MEN
#       - link:
#         - /url: /men/footwear/dice
#       - link:
#         - /url: /men/footwear/dice
#       - img "A stylish sneaker with a brown and white pattern, cream laces, and a brown sole, viewed from the front against a plain background."
#       - 'link "DICE T-TOE PONY: A BOLD NEW FEEL"':
#         - /url: /women/footwear/dice
#         - paragraph: "DICE T-TOE PONY: A BOLD NEW FEEL"
#       - link:
#         - /url: /women/footwear/dice
#       - link "SHOP WOMEN":
#         - /url: /women/footwear/dice
#         - img
#         - text: SHOP WOMEN
#       - link:
#         - /url: /women/footwear/dice
#       - link:
#         - /url: /women/footwear/dice
#       - text: ESSENTIALS
#       - button "Men" [disabled]
#       - button "Women"
#       - button:
#         - img
#       - link "Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD":
#         - /url: /men/footwear/orbit/orbit-vintage-sneaker-f3216001
#         - img "Orbit Vintage Sneaker"
#         - paragraph: Orbit Vintage Sneaker
#         - text: 350 USD
#       - button:
#         - img
#       - link "Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD":
#         - /url: /men/footwear/dice/dice-t-toe-sneaker-f3032001
#         - img "Dice T-Toe Sneaker"
#         - paragraph: Dice T-Toe Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD":
#         - /url: /men/footwear/area/area-lo-sneaker-f2279001
#         - img "Area Lo Fluffy Sneaker"
#         - paragraph: Area Lo Fluffy Sneaker
#         - text: 420 USD
#       - button:
#         - img
#       - link "Clean 90 Sneaker Clean 90 Sneaker 325 USD":
#         - /url: /men/footwear/clean-90/clean-90-28102
#         - img "Clean 90 Sneaker"
#         - paragraph: Clean 90 Sneaker
#         - text: 325 USD
#       - button:
#         - img
#       - link "Atlas Sneaker Atlas Sneaker 345 USD":
#         - /url: /men/footwear/atlas/atlas-sneaker-f3600002
#         - img "Atlas Sneaker"
#         - paragraph: Atlas Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD":
#         - /url: /men/footwear/dice/dice-t-toe-sneaker-f3625003
#         - img "Dice T-Toe Sneaker"
#         - paragraph: Dice T-Toe Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Genesis Neo Bird Runner Genesis Neo Bird Runner 345 USD":
#         - /url: /men/footwear/genesis/genesis-neo-bird-runner-f3572001
#         - img "Genesis Neo Bird Runner"
#         - paragraph: Genesis Neo Bird Runner
#         - text: 345 USD
#       - button:
#         - img
#       - link "Clay Sneaker Clay Sneaker 365 USD":
#         - /url: /men/footwear/clay/clay-sneaker-f3559001
#         - img "Clay Sneaker"
#         - paragraph: Clay Sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f3535004
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD":
#         - /url: /men/footwear/clean-90/cap-toe-sneaker-f4273001
#         - img "Clean 90 Cap-Toe Sneaker"
#         - paragraph: Clean 90 Cap-Toe Sneaker
#         - text: 325 USD
#       - button:
#         - img
#       - link "Clay Sneaker Clay Sneaker 365 USD":
#         - /url: /men/footwear/clay/clay-sneaker-f2538004
#         - img "Clay Sneaker"
#         - paragraph: Clay Sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD":
#         - /url: /men/footwear/orbit/orbit-vintage-sneaker-f3216003
#         - img "Orbit Vintage Sneaker"
#         - paragraph: Orbit Vintage Sneaker
#         - text: 350 USD
#       - img "Stack of three stylish sneakers in dark gray, beige, and cream with orange accents against a plain white background."
#       - 'link "ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT."':
#         - /url: /men/footwear/orbit
#         - paragraph: "ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT."
#       - link:
#         - /url: /men/footwear/orbit
#       - link "SHOP MEN":
#         - /url: /men/footwear/orbit
#         - img
#         - text: SHOP MEN
#       - link:
#         - /url: /men/footwear/orbit
#       - link:
#         - /url: /men/footwear/orbit
#       - link "A pair of beige and orange sneakers, with one showing the side profile and the other displaying the gum sole, on a light gray background.":
#         - /url: /men/new-arrivals
#         - img "A pair of beige and orange sneakers, with one showing the side profile and the other displaying the gum sole, on a light gray background."
#       - text: NEW ARRIVALS
#       - link "DISCOVER MEN":
#         - /url: /men/new-arrivals
#         - img
#         - text: DISCOVER MEN
#       - link "DISCOVER WOMEN":
#         - /url: /women/new-arrivals
#         - img
#         - text: DISCOVER WOMEN
#       - link "DJ wearing headphones, adjusting the mixer at a booth, focused under stage lighting, with people and cups visible in the dim background.":
#         - /url: https://axelarigato.com/events
#         - img "DJ wearing headphones, adjusting the mixer at a booth, focused under stage lighting, with people and cups visible in the dim background."
#       - text: COMMUNITY
#       - link "DISCOVER":
#         - /url: https://axelarigato.com/events
#         - img
#         - text: DISCOVER
#       - link "Two neatly coiled lavender shoelaces on a white background, showcasing their woven texture and soft pastel color.":
#         - /url: /extra-laces-men
#         - img "Two neatly coiled lavender shoelaces on a white background, showcasing their woven texture and soft pastel color."
#       - text: EXTRA LACES
#       - link "DISCOVER MEN":
#         - /url: /extra-laces-men
#         - img
#         - text: DISCOVER MEN
#       - link "DISCOVER WOMEN":
#         - /url: /extra-laces-women
#         - img
#         - text: DISCOVER WOMEN
#       - link "Street corner with a brick building housing the Axel Arigato store, displaying modern interiors through large windows. Traffic light and crosswalk visible.":
#         - /url: /stores
#         - img "Street corner with a brick building housing the Axel Arigato store, displaying modern interiors through large windows. Traffic light and crosswalk visible."
#       - text: FIND A STORE
#       - link "DISCOVER":
#         - /url: /stores
#         - img
#         - text: DISCOVER
#     - paragraph: Subscribe to our newsletter for exclusive updates on drops, sales & events.
#     - textbox "JOIN THE COMMUNITY"
#     - text: JOIN THE COMMUNITY
#     - contentinfo:
#       - button "Company":
#         - text: Company
#         - img
#       - button "Customer Support":
#         - text: Customer Support
#         - img
#       - button "Community":
#         - text: Community
#         - img
#       - button "Language / en":
#         - text: Language / en
#         - img
#       - button "Shipping To / United States of America":
#         - text: Shipping To / United States of America
#         - img
#       - img
#     - alert
#     - iframe
#     - img
#     - text: 1 Unblock Notifications
#     - paragraph: "Follow these instructions to allow notifications:"
#     - text: axelarigato.com
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 72 elements from ARIA:
#     [button] DISCOVER THE SS26 EDIT (url=None)
#     [link] DISCOVER THE SS26 EDIT (url=/men-ss26-edit)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [button] Shoes (url=None)
#     [button] Shoes (url=None)
#     [button] Clothing (url=None)
#     [button] Clothing (url=None)
#     [button] Accessories (url=None)
#     [button] Accessories (url=None)
#     [link] New Arrivals (url=/women/new-arrivals)
#     [button] New Arrivals (url=None)
#     [link] Top Sellers (url=/women/top-sellers)
#     [button] Top Sellers (url=None)
#     [link] SS26 EDITNEW (url=/women-ss26-edit)
#     [button] SS26 EDITNEW (url=None)
#     [link] View all women (url=/women)
#     [button] View all women (url=None)
#     [link] Customer Support (url=/contact)
#     [button] Customer Support (url=None)
#     [button] Language / en English (url=None)
#     [link] DAZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIG
AZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIGN.
#       - DICE T-TOE: ICONIC. BACK IN STOCK.
#       - DICE T-TOE PONY: A BOLD NEW FEEL
#       - ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT.
#     div (7 items):
#       - New Arrivals
#       - Top Sellers
#       - SS26 EDITNEW
#       - View all women
#       - Customer Support
#       - Company
#       - Community
#     a (6 items):
#       - New Arrivals
#       - Top Sellers
#       - SS26 EDITNEW
#       - View all women
#       - Customer Support
#       - Customer Support
#     relative (7 items):
#       - Language / en English
#       - SHOP MEN
#       - SHOP WOMEN
#       - SHOP MEN
#       - SHOP WOMEN
#       - SHOP MEN
#       - Language / en
#     group (24 items):
#       - Slow Runner Slow Runner 385 USD
#       - Daze Runner Daze Runner 330 USD
#       - Daze Runner Daze Runner 330 USD
#       - Eris Sneaker Eris Sneaker 450 USD
#       - Daze Runner Daze Runner 330 USD
#       - Slow Runner Slow Runner 385 USD
#       - Eris Sneaker Eris Sneaker 465 USD
#       - Squish Sneaker Squish Sneaker 365 USD
#       - Slow Runner Slow Runner 385 USD
#       - Eris Sneaker Eris Sneaker 465 USD
#       - Daze Runner Daze Runner 330 USD
#       - Grain Sneaker Grain Sneaker 495 USD
#       - Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD
#       - Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD
#       - Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD
#       - Clean 90 Sneaker Clean 90 Sneaker 325 USD
#       - Atlas Sneaker Atlas Sneaker 345 USD
#       - Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD
#       - Genesis Neo Bird Runner Genesis Neo Bird Runner 345 USD
#       - Clay Sneaker Clay Sneaker 365 USD
#       - Daze Runner Daze Runner 330 USD
#       - Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD
#       - Clay Sneaker Clay Sneaker 365 USD
#       - Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD
#     flex (6 items):
#       - DISCOVER MEN
#       - DISCOVER WOMEN
#       - DISCOVER
#       - DISCOVER MEN
#       - DISCOVER WOMEN
#       - DISCOVER
#   [EXTRACT] Using cached CSS exclusions: {'div', 'flex', 'col-span-4', 'relative', 'a'}
#   [EXTRACT] excluded_groups={'div', 'flex', 'col-span-4', 'relative', 'a'}
#   [EXTRACT] Excluded: ['Toggle mobile wishlist (class=col-span-4)', 'Toggle mobile wishlist (class=col-span-4)', 'Toggle mobile wishlist (class=col-span-4)', 'Men (class=col-span-4)', 'New Arrivals (class=div)', 'New Arrivals (class=a)', 'Top Sellers (class=div)', 'Top Sellers (class=a)', 'SS26 EDITNEW (class=div)', 'SS26 EDITNEW (class=a)', 'View all women (class=div)', 'View all women (class=a)', 'Customer Support (class=div)', 'Customer Support (class=a)', 'Language / en English (class=relative)', 'SHOP MEN (class=relative)', 'SHOP WOMEN (class=relative)', 'Men (class=col-span-4)', 'SHOP MEN (class=relative)', 'SHOP WOMEN (class=relative)', 'Men (class=col-span-4)', 'SHOP MEN (class=relative)', 'DISCOVER MEN (class=flex)', 'DISCOVER WOMEN (class=flex)', 'DISCOVER (class=flex)', 'DISCOVER MEN (class=flex)', 'DISCOVER WOMEN (class=flex)', 'DISCOVER (class=flex)', 'Company (class=div)', 'Customer Support (class=a)', 'Community (class=div)', 'Language / en (class=relative)']
#   [EXTRACT] After CSS filter: 40 elements
#   [CLICK] Women
#         [CLICK-DETAIL] Strict role search: only trying 'button'
#         [CLICK-DETAIL] button exact=True: 3 matches
#         [CLICK-DEBUG] WARNING: Found 3 elements for 'Women' as button
#         [CLICK-DETAIL] Found 'Women' as button (#1 of 3, visible)
#   [ARIA] WARNING: No menu container found, using body
#   [ARIA AFTER] 15873 chars, 524 lines
#     - main:
#       - button "FREE EXPRESS DELIVERY":
#         - link "FREE EXPRESS DELIVERY":
#           - /url: /assistance?group=shipping-and-delivery&faq=which-delivery-services-do-you-offer-how-much-do-they-cost-and-how-long-do-they-take
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - navigation
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - searchbox "Search"
#       - button "Close search":
#         - img
#       - text: Search
#       - link:
#         - /url: /
#         - img
#       - button "Search":
#         - img
#       - button "Toggle mobile wishlist":
#         - img
#       - button "Toggle mobile cart":
#         - img
#       - button "Toggle mobile primaryMenu":
#         - img
#       - button "Men"
#       - button "Women"
#       - button "Shoes":
#         - button "Shoes":
#           - text: Shoes
#           - img
#       - button "Clothing":
#         - button "Clothing":
#           - text: Clothing
#           - img
#       - button "Accessories":
#         - button "Accessories":
#           - text: Accessories
#           - img
#       - link "New Arrivals":
#         - /url: /women/new-arrivals
#         - button "New Arrivals"
#       - link "Top Sellers":
#         - /url: /women/top-sellers
#         - button "Top Sellers"
#       - link "SS26 EDITNEW":
#         - /url: /women-ss26-edit
#         - button "SS26 EDITNEW"
#       - link "View all women":
#         - /url: /women
#         - button "View all women"
#       - link "Brown suede sneakers with white laces on a textured beige surface. The soles are black with a distinct pattern. DAZE RUNNER SHOP NOW":
#         - /url: /women/footwear/daze
#         - img "Brown suede sneakers with white laces on a textured beige surface. The soles are black with a distinct pattern."
#         - text: DAZE RUNNER
#         - img
#         - text: SHOP NOW
#       - link "Customer Support":
#         - /url: /contact
#         - button "Customer Support":
#           - text: Customer Support
#           - img
#       - button "Language / en English":
#         - text: Language / en
#         - img
#         - combobox:
#           - option "English" [selected]
#           - option "French"
#           - option "German"
#       - button "Shipping To / United States of America United States of America":
#         - text: Shipping To / United States of America
#         - img
#         - combobox:
#           - option "Select Country" [disabled]
#           - option "Albania"
#           - option "Andorra"
#           - option "Anguilla"
#           - option "Argentina"
#           - option "Aruba"
#           - option "Australia"
#           - option "Austria"
#           - option "Azerbaijan"
#           - option "Bahamas"
#           - option "Bahrain"
#           - option "Bangladesh"
#           - option "Barbados"
#           - option "Belgium"
#           - option "Belize"
#           - option "Bermuda"
#           - option "Bhutan"
#           - option "Bolivia"
#           - option "Bosnia and Herzegovina"
#           - option "Brunei Darussalam"
#           - option "Bulgaria"
#           - option "Cambodia"
#           - option "Canada"
#           - option "Cayman Islands"
#           - option "Chile"
#           - option "China Mainland"
#           - option "Colombia"
#           - option "Costa Rica"
#           - option "Croatia"
#           - option "Cyprus"
#           - option "Czech Republic"
#           - option "Denmark"
#           - option "Dominica"
#           - option "Dominican Republic"
#           - option "Ecuador"
#           - option "Egypt"
#           - option "El Salvador"
#           - option "Estonia"
#           - option "Finland"
#           - option "France"
#           - option "French Guiana"
#           - option "French Polynesia"
#           - option "Germany"
#           - option "Gibraltar"
#           - option "Greece"
#           - option "Greenland"
#           - option "Grenada"
#           - option "Guadeloupe"
#           - option "Guernsey"
#           - option "Holy See (Vatican City State)"
sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Slow Runner Slow Runner 385 USD":
#         - /url: /men/footwear/slow/slow-runner-f3644002
#         - img "Slow Runner"
#         - paragraph: Slow Runner
#         - text: 385 USD
#       - button:
#         - img
#       - link "Eris Sneaker Eris Sneaker 465 USD":
#         - /url: /men/footwear/eris/eris-sneaker-f3911003
#         - img "Eris Sneaker"
#         - paragraph: Eris Sneaker
#         - text: 465 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f3617003
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Grain Sneaker Grain Sneaker 495 USD":
#         - /url: /men/footwear/grain/grain-sneaker-f3928002
#         - img "Grain Sneaker"
#         - paragraph: Grain Sneaker
#         - text: 495 USD
#       - img "Black Arcato sneaker with white laces and gray sole, placed on a light-checkered surface."
#       - 'link "DICE T-TOE: ICONIC. BACK IN STOCK."':
#         - /url: /men/footwear/dice
#         - paragraph: "DICE T-TOE: ICONIC. BACK IN STOCK."
#       - link:
#         - /url: /men/footwear/dice
#       - link "SHOP MEN":
#         - /url: /men/footwear/dice
#         - img
#         - text: SHOP MEN
#       - link:
#         - /url: /men/footwear/dice
#       - link:
#         - /url: /men/footwear/dice
#       - img "A stylish sneaker with a brown and white pattern, cream laces, and a brown sole, viewed from the front against a plain background."
#       - 'link "DICE T-TOE PONY: A BOLD NEW FEEL"':
#         - /url: /women/footwear/dice
#         - paragraph: "DICE T-TOE PONY: A BOLD NEW FEEL"
#       - link:
#         - /url: /women/footwear/dice
#       - link "SHOP WOMEN":
#         - /url: /women/footwear/dice
#         - img
#         - text: SHOP WOMEN
#       - link:
#         - /url: /women/footwear/dice
#       - link:
#         - /url: /women/footwear/dice
#       - text: ESSENTIALS
#       - button "Men" [disabled]
#       - button "Women"
#       - button:
#         - img
#       - link "Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD":
#         - /url: /men/footwear/orbit/orbit-vintage-sneaker-f3216001
#         - img "Orbit Vintage Sneaker"
#         - paragraph: Orbit Vintage Sneaker
#         - text: 350 USD
#       - button:
#         - img
#       - link "Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD":
#         - /url: /men/footwear/dice/dice-t-toe-sneaker-f3032001
#         - img "Dice T-Toe Sneaker"
#         - paragraph: Dice T-Toe Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD":
#         - /url: /men/footwear/area/area-lo-sneaker-f2279001
#         - img "Area Lo Fluffy Sneaker"
#         - paragraph: Area Lo Fluffy Sneaker
#         - text: 420 USD
#       - button:
#         - img
#       - link "Clean 90 Sneaker Clean 90 Sneaker 325 USD":
#         - /url: /men/footwear/clean-90/clean-90-28102
#         - img "Clean 90 Sneaker"
#         - paragraph: Clean 90 Sneaker
#         - text: 325 USD
#       - button:
#         - img
#       - link "Atlas Sneaker Atlas Sneaker 345 USD":
#         - /url: /men/footwear/atlas/atlas-sneaker-f3600002
#         - img "Atlas Sneaker"
#         - paragraph: Atlas Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD":
#         - /url: /men/footwear/dice/dice-t-toe-sneaker-f3625003
#         - img "Dice T-Toe Sneaker"
#         - paragraph: Dice T-Toe Sneaker
#         - text: 345 USD
#       - button:
#         - img
#       - link "Genesis Neo Bird Runner Genesis Neo Bird Runner 345 USD":
#         - /url: /men/footwear/genesis/genesis-neo-bird-runner-f3572001
#         - img "Genesis Neo Bird Runner"
#         - paragraph: Genesis Neo Bird Runner
#         - text: 345 USD
#       - button:
#         - img
#       - link "Clay Sneaker Clay Sneaker 365 USD":
#         - /url: /men/footwear/clay/clay-sneaker-f3559001
#         - img "Clay Sneaker"
#         - paragraph: Clay Sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Daze Runner Daze Runner 330 USD":
#         - /url: /men/footwear/daze/daze-runner-f3535004
#         - img "Daze Runner"
#         - paragraph: Daze Runner
#         - text: 330 USD
#       - button:
#         - img
#       - link "Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD":
#         - /url: /men/footwear/clean-90/cap-toe-sneaker-f4273001
#         - img "Clean 90 Cap-Toe Sneaker"
#         - paragraph: Clean 90 Cap-Toe Sneaker
#         - text: 325 USD
#       - button:
#         - img
#       - link "Clay Sneaker Clay Sneaker 365 USD":
#         - /url: /men/footwear/clay/clay-sneaker-f2538004
#         - img "Clay Sneaker"
#         - paragraph: Clay Sneaker
#         - text: 365 USD
#       - button:
#         - img
#       - link "Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD":
#         - /url: /men/footwear/orbit/orbit-vintage-sneaker-f3216003
#         - img "Orbit Vintage Sneaker"
#         - paragraph: Orbit Vintage Sneaker
#         - text: 350 USD
#       - img "Stack of three stylish sneakers in dark gray, beige, and cream with orange accents against a plain white background."
#       - 'link "ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT."':
#         - /url: /men/footwear/orbit
#         - paragraph: "ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT."
#       - link:
#         - /url: /men/footwear/orbit
#       - link "SHOP MEN":
#         - /url: /men/footwear/orbit
#         - img
#         - text: SHOP MEN
#       - link:
#         - /url: /men/footwear/orbit
#       - link:
#         - /url: /men/footwear/orbit
#       - link "A pair of beige and orange sneakers, with one showing the side profile and the other displaying the gum sole, on a light gray background.":
#         - /url: /men/new-arrivals
#         - img "A pair of beige and orange sneakers, with one showing the side profile and the other displaying the gum sole, on a light gray background."
#       - text: NEW ARRIVALS
#       - link "DISCOVER MEN":
#         - /url: /men/new-arrivals
#         - img
#         - text: DISCOVER MEN
#       - link "DISCOVER WOMEN":
#         - /url: /women/new-arrivals
#         - img
#         - text: DISCOVER WOMEN
#       - link "DJ wearing headphones, adjusting the mixer at a booth, focused under stage lighting, with people and cups visible in the dim background.":
#         - /url: https://axelarigato.com/events
#         - img "DJ wearing headphones, adjusting the mixer at a booth, focused under stage lighting, with people and cups visible in the dim background."
#       - text: COMMUNITY
#       - link "DISCOVER":
#         - /url: https://axelarigato.com/events
#         - img
#         - text: DISCOVER
#       - link "Two neatly coiled lavender shoelaces on a white background, showcasing their woven texture and soft pastel color.":
#         - /url: /extra-laces-men
#         - img "Two neatly coiled lavender shoelaces on a white background, showcasing their woven texture and soft pastel color."
#       - text: EXTRA LACES
#       - link "DISCOVER MEN":
#         - /url: /extra-laces-men
#         - img
#         - text: DISCOVER MEN
#       - link "DISCOVER WOMEN":
#         - /url: /extra-laces-women
#         - img
#         - text: DISCOVER WOMEN
#       - link "Street corner with a brick building housing the Axel Arigato store, displaying modern interiors through large windows. Traffic light and crosswalk visible.":
#         - /url: /stores
#         - img "Street corner with a brick building housing the Axel Arigato store, displaying modern interiors through large windows. Traffic light and crosswalk visible."
#       - text: FIND A STORE
#       - link "DISCOVER":
#         - /url: /stores
#         - img
#         - text: DISCOVER
#     - paragraph: Subscribe to our newsletter for exclusive updates on drops, sales & events.
#     - textbox "JOIN THE COMMUNITY"
#     - text: JOIN THE COMMUNITY
#     - contentinfo:
#       - button "Company":
#         - text: Company
#         - img
#       - button "Customer Support":
#         - text: Customer Support
#         - img
#       - button "Community":
#         - text: Community
#         - img
#       - button "Language / en":
#         - text: Language / en
#         - img
#       - button "Shipping To / United States of America":
#         - text: Shipping To / United States of America
#         - img
#       - img
#     - alert
#     - iframe
#     - img
#     - text: 1 Unblock Notifications
#     - paragraph: "Follow these instructions to allow notifications:"
#     - text: axelarigato.com
#   [EXTRACT] Starting extraction...
#   [EXTRACT] Parsed 72 elements from ARIA:
#     [button] FREE EXPRESS DELIVERY (url=None)
#     [link] FREE EXPRESS DELIVERY (url=/assistance?group=shipping-and-delivery&faq=which-delivery-services-do-you-offer-how-much-do-they-cost-and-how-long-do-they-take)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Toggle mobile wishlist (url=None)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [button] Shoes (url=None)
#     [button] Shoes (url=None)
#     [button] Clothing (url=None)
#     [button] Clothing (url=None)
#     [button] Accessories (url=None)
#     [button] Accessories (url=None)
#     [link] New Arrivals (url=/women/new-arrivals)
#     [button] New Arrivals (url=None)
#     [link] Top Sellers (url=/women/top-sellers)
#     [button] Top Sellers (url=None)
#     [link] SS26 EDITNEW (url=/women-ss26-edit)
#     [button] SS26 EDITNEW (url=None)
#     [link] View all women (url=/women)
#     [button] View all women (url=None)
#     [link] Customer Support (url=/contact)
#     [button] Customer Support (url=None)
#     [button] Language / en English (url=None)
#     [link] DAZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIGN. (url=/men/footwear/daze)
#     [link] SHOP MEN (url=/men/footwear/daze)
#     [link] SHOP WOMEN (url=/women/footwear/daze)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3694001)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3617001)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3683002)
#     [link] Eris Sneaker Eris Sneaker 450 USD (url=/men/footwear/eris/eris-sneaker-f3567002)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f4031001)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3644003)
#     [link] Eris Sneaker Eris Sneaker 465 USD (url=/men/footwear/eris/eris-sneaker-f3911001)
#     [link] Squish Sneaker Squish Sneaker 365 USD (url=/men/footwear/squish/squish-sneaker-f3654002)
#     [link] Slow Runner Slow Runner 385 USD (url=/men/footwear/slow/slow-runner-f3644002)
#     [link] Eris Sneaker Eris Sneaker 465 USD (url=/men/footwear/eris/eris-sneaker-f3911003)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3617003)
#     [link] Grain Sneaker Grain Sneaker 495 USD (url=/men/footwear/grain/grain-sneaker-f3928002)
#     [link] DICE T-TOE: ICONIC. BACK IN STOCK. (url=/men/footwear/dice)
#     [link] SHOP MEN (url=/men/footwear/dice)
#     [link] DICE T-TOE PONY: A BOLD NEW FEEL (url=/women/footwear/dice)
#     [link] SHOP WOMEN (url=/women/footwear/dice)
#     [button] Men (url=None)
#     [button] Women (url=None)
#     [link] Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD (url=/men/footwear/orbit/orbit-vintage-sneaker-f3216001)
#     [link] Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD (url=/men/footwear/dice/dice-t-toe-sneaker-f3032001)
#     [link] Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD (url=/men/footwear/area/area-lo-sneaker-f2279001)
#     [link] Clean 90 Sneaker Clean 90 Sneaker 325 USD (url=/men/footwear/clean-90/clean-90-28102)
#     [link] Atlas Sneaker Atlas Sneaker 345 USD (url=/men/footwear/atlas/atlas-sneaker-f3600002)
#     [link] Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD (url=/men/footwear/dice/dice-t-toe-sneaker-f3625003)
#     [link] Genesis Neo Bird Runner Genesis Neo Bird Runner 345 USD (url=/men/footwear/genesis/genesis-neo-bird-runner-f3572001)
#     [link] Clay Sneaker Clay Sneaker 365 USD (url=/men/footwear/clay/clay-sneaker-f3559001)
#     [link] Daze Runner Daze Runner 330 USD (url=/men/footwear/daze/daze-runner-f3535004)
#     [link] Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD (url=/men/footwear/clean-90/cap-toe-sneaker-f4273001)
#     [link] Clay Sneaker Clay Sneaker 365 USD (url=/men/footwear/clay/clay-sneaker-f2538004)
#     [link] Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD (url=/men/footwear/orbit/orbit-vintage-sneaker-f3216003)
#     [link] ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT. (url=/men/footwear/orbit)
#     [link] SHOP MEN (url=/men/footwear/orbit)
#     [link] DISCOVER MEN (url=/men/new-arrivals)
#     [link] DISCOVER WOMEN (url=/women/new-arrivals)
#     [link] DISCOVER (url=https://axelarigato.com/events)
#     [link] DISCOVER MEN (url=/extra-laces-men)
#     [link] DISCOVER WOMEN (url=/extra-laces-women)
#     [link] DISCOVER (url=/stores)
#     [button] Company (url=None)
#     [button] Customer Support (url=None)
#     [button] Community (url=None)
#     [button] Language / en (url=None)
#     [button] Shipping To / United States of America (url=None)
#   [EXTRACT] CSS groups: 8
#     col-span-4 (6 items):
#       - Toggle mobile wishlist
#       - Toggle mobile wishlist
#       - Toggle mobile wishlist
#       - Men
#       - Men
#       - Men
#     scrollbar-hide (3 items):
#       - Women
#       - Women
#       - Women
#     w-full (10 items):
#       - Shoes
#       - Shoes
#       - Clothing
#       - Clothing
#       - Accessories
#       - Accessories
#       - DAZE RIPSTOP: SPORT-INSPIRED, UNISEX DESIGN.
#       - DICE T-TOE: ICONIC. BACK IN STOCK.
#       - DICE T-TOE PONY: A BOLD NEW FEEL
#       - ORBIT EDGE: RETRO INSPIRATION. MODERN CRAFT.
#     div (7 items):
#       - New Arrivals
#       - Top Sellers
#       - SS26 EDITNEW
#       - View all women
#       - Customer Support
#       - Company
#       - Community
#     a (6 items):
#       - New Arrivals
#       - Top Sellers
#       - SS26 EDITNEW
#       - View all women
#       - Customer Support
#       - Customer Support
#     relative (7 items):
#       - Language / en English
#       - SHOP MEN
#       - SHOP WOMEN
#       - SHOP MEN
#       - SHOP WOMEN
#       - SHOP MEN
#       - Language / en
#     group (24 items):
#       - Slow Runner Slow Runner 385 USD
#       - Daze Runner Daze Runner 330 USD
#       - Daze Runner Daze Runner 330 USD
#       - Eris Sneaker Eris Sneaker 450 USD
#       - Daze Runner Daze Runner 330 USD
#       - Slow Runner Slow Runner 385 USD
#       - Eris Sneaker Eris Sneaker 465 USD
#       - Squish Sneaker Squish Sneaker 365 USD
#       - Slow Runner Slow Runner 385 USD
#       - Eris Sneaker Eris Sneaker 465 USD
#       - Daze Runner Daze Runner 330 USD
#       - Grain Sneaker Grain Sneaker 495 USD
#       - Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD
#       - Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD
#       - Area Lo Fluffy Sneaker Area Lo Fluffy Sneaker 420 USD
#       - Clean 90 Sneaker Clean 90 Sneaker 325 USD
#       - Atlas Sneaker Atlas Sneaker 345 USD
#       - Dice T-Toe Sneaker Dice T-Toe Sneaker 345 USD
#       - Genesis Neo Bird Runner Genesis Neo Bird Runner 345 USD
#       - Clay Sneaker Clay Sneaker 365 USD
#       - Daze Runner Daze Runner 330 USD
#       - Clean 90 Cap-Toe Sneaker Clean 90 Cap-Toe Sneaker 325 USD
#       - Clay Sneaker Clay Sneaker 365 USD
#       - Orbit Vintage Sneaker Orbit Vintage Sneaker 350 USD
#     flex (6 items):
#       - DISCOVER MEN
#       - DISCOVER WOMEN
#       - DISCOVER
#       - DISCOVER MEN
#       - DISCOVER WOMEN
#       - DISCOVER
#   [EXTRACT] Using cached CSS exclusions: {'div', 'flex', 'col-span-4', 'relative', 'a'}
#   [EXTRACT] excluded_groups={'div', 'flex', 'col-span-4', 'relative', 'a'}
#   [EXTRACT] Excluded: ['Toggle mobile wishlist (class=col-span-4)', 'Toggle mobile wishlist (class=col-span-4)', 'Toggle mobile wishlist (class=col-span-4)', 'Men (class=col-span-4)', 'New Arrivals (class=div)', 'New Arrivals (class=a)', 'Top Sellers (class=div)', 'Top Sellers (class=a)', 'SS26 EDITNEW (class=div)', 'SS26 EDITNEW (class=a)', 'View all women (class=div)', 'View all women (class=a)', 'Customer Support (class=div)', 'Customer Support (class=a)', 'Language / en English (class=relative)', 'SHOP MEN (class=relative)', 'SHOP WOMEN (class=relative)', 'Men (class=col-span-4)', 'SHOP MEN (class=relative)', 'SHOP WOMEN (class=relative)', 'Men (class=col-span-4)', 'SHOP MEN (class=relative)', 'DISCOVER MEN (class=flex)', 'DISCOVER WOMEN (class=flex)', 'DISCOVER (class=flex)', 'DISCOVER MEN (class=flex)', 'DISCOVER WOMEN (class=flex)', 'DISCOVER (class=flex)', 'Company (class=div)', 'Customer Support (class=a)', 'Community (class=div)', 'Language / en (class=relative)']
#   [EXTRACT] After CSS filter: 40 elements
#   [SUBMENU] Using position-based diff (back button detected)
#   [DIFF] 2 new elements (by position):
#     [button] FREE EXPRESS DELIVERY (idx:?, near:None)
#     [link] FREE EXPRESS DELIVERY (idx:?, near:None)
#   [NAV] Link: FREE EXPRESS DELIVERY
#   [NAV] Expandable: FREE EXPRESS DELIVERY (has children, skipped)
#   [NAV] Total: 1 links added, 0 expandables queued
#   [TREE] Total categories: 2
#   [STACK] Added 0 (LIFO - last added = next to pop)
#   [STACK] (0 items, top first):
# 1. Women: 1 links, 0 children
# Done!
#
# ==================================================
# Stack: 0
# Explored: 2
# Categories: 2
# ==================================================

# %%
# SHOW TREE: Print categories as tree
explorer.print_tree()

print(f"\nExplored: {len(explorer.explored)}")
print(f"Remaining: {len(explorer.stack)}")
# Out:
# [TREE] 2 categories
# ├── Men
# │   └── FREE RETURNS
# │       └── FREE RETURNS → /assistance?group=returns-and-exchanges&faq=what-is-your-return-policy
# └── Women
#     └── FREE EXPRESS DELIVERY
#         └── FREE EXPRESS DELIVERY → /assistance?group=shipping-and-delivery&faq=which-delivery-services-do-you-offer-how-much-do-they-cost-and-how-long-do-they-take
#
# Explored: 2
# Remaining: 0

# %%
# UTILITIES
# explorer.stack  # Direct access to stack
# explorer.explored  # Set of explored paths
# explorer.categories  # Dict of path -> url
# explorer.css_cache  # Cached CSS classes per depth

# %%
# Scratch cell
